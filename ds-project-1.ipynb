# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import math

# %%
data = pd.read_csv("college_student_placement_dataset.csv")

# %%
data.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# 3                   1        No
# 4                   2        No

# %%
no_yes_dict = {"No":0,"Yes":1}
data[data.columns[5]] = data[data.columns[5]].map(no_yes_dict)
data[data.columns[-1]] =data[data.columns[-1]].map(no_yes_dict)

# %%
data[data.columns[0]] = data[data.columns[0]].apply(lambda x: int(x[3:]))

# %%
data.head()
# Out:
#    College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0          30  107             6.61  6.28                     8
# 1          61   97             5.52  5.37                     8
# 2          36  109             5.36  5.83                     9
# 3          55  122             5.47  5.75                     6
# 4           4   96             7.91  7.69                     7
#
#    Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                      0                       8                     8
# 1                      0                       7                     8
# 2                      0                       3                     1
# 3                      1                       1                     6
# 4                      0                       8                    10
#
#    Projects_Completed  Placement
# 0                   4          0
# 1                   0          0
# 2                   1          0
# 3                   1          0
# 4                   2          0

# %%
corr_matrix = data.corr()

# %%
corr_matrix
# Out:
#                         College_ID        IQ  Prev_Sem_Result      CGPA  \
# College_ID                1.000000  0.002473        -0.004060 -0.003422
# IQ                        0.002473  1.000000        -0.002640 -0.002859
# Prev_Sem_Result          -0.004060 -0.002640         1.000000  0.980768
# CGPA                     -0.003422 -0.002859         0.980768  1.000000
# Academic_Performance     -0.015442 -0.006827        -0.005765 -0.002958
# Internship_Experience     0.012037 -0.000247        -0.013347 -0.012562
# Extra_Curricular_Score   -0.003931 -0.003458         0.009326  0.011441
# Communication_Skills     -0.005194 -0.010896        -0.017269 -0.018242
# Projects_Completed        0.004903  0.014538         0.018434  0.020872
# Placement                 0.002750  0.285914         0.317896  0.321607
#
#                         Academic_Performance  Internship_Experience  \
# College_ID                         -0.015442               0.012037
# IQ                                 -0.006827              -0.000247
# Prev_Sem_Result                    -0.005765              -0.013347
# CGPA                               -0.002958              -0.012562
# Academic_Performance                1.000000               0.025903
# Internship_Experience               0.025903               1.000000
# Extra_Curricular_Score              0.011774               0.002093
# Communication_Skills               -0.019733              -0.020437
# Projects_Completed                 -0.013148              -0.010260
# Placement                          -0.014920              -0.005841
#
#                         Extra_Curricular_Score  Communication_Skills  \
# College_ID                           -0.003931             -0.005194
# IQ                                   -0.003458             -0.010896
# Prev_Sem_Result                       0.009326             -0.017269
# CGPA                                  0.011441             -0.018242
# Academic_Performance                  0.011774             -0.019733
# Internship_Experience                 0.002093             -0.020437
# Extra_Curricular_Score                1.000000              0.003769
# Communication_Skills                  0.003769              1.000000
# Projects_Completed                    0.008122             -0.004486
# Placement                            -0.004740              0.323155
#
#                         Projects_Completed  Placement
# College_ID                        0.004903   0.002750
# IQ                                0.014538   0.285914
# Prev_Sem_Result                   0.018434   0.317896
# CGPA                              0.020872   0.321607
# Academic_Performance             -0.013148  -0.014920
# Internship_Experience            -0.010260  -0.005841
# Extra_Curricular_Score            0.008122  -0.004740
# Communication_Skills             -0.004486   0.323155
# Projects_Completed                1.000000   0.217499
# Placement                         0.217499   1.000000

# %%
feature_selected_data = data[[data.columns[1],data.columns[2],
                             data.columns[3],data.columns[7],
                             data.columns[8],data.columns[9]]]

# %%
feature_selected_data.head()
# Out:
#     IQ  Prev_Sem_Result  CGPA  Communication_Skills  Projects_Completed  \
# 0  107             6.61  6.28                     8                   4
# 1   97             5.52  5.37                     8                   0
# 2  109             5.36  5.83                     1                   1
# 3  122             5.47  5.75                     6                   1
# 4   96             7.91  7.69                    10                   2
#
#    Placement
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
placement_equals_1_prior = data[data[data.columns[-1]] == 1].shape[0]/data.shape[0]

# %%
placement_equals_1_prior
# Out:
# 0.1659

# %%
sns.heatmap(feature_selected_data.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(feature_selected_data.iloc[:,0:-1].corr(),annot=True)
# Out:
# <Axes: >

# %%
X = np.array(feature_selected_data.iloc[:,0:-1])
cov_mat = np.cov(X,rowvar=False)
F = np.linalg.svd(cov_mat)

# %%
E = F[0]
lamda = F[1]
new_X = np.matmul(X,F[0])
new_cov_mat = np.cov(new_X,rowvar=False)

# %%
new_input_features = pd.DataFrame(data=new_X,
                            columns=["Input_feat_1", "Input_feat_2","Input_feat_3",
                                     "Input_feat_4","Input_feat_5"])

# %%
new_input_features
# Out:
#       Input_feat_1  Input_feat_2  Input_feat_3  Input_feat_4  Input_feat_5
# 0      -106.985375     -7.981836     -9.555150      3.340004     -0.306328
# 1       -96.979236     -8.012939     -7.923885     -0.560073     -0.162169
# 2      -108.996045     -1.031525     -8.018326      0.386976      0.270885
# 3      -121.985085     -6.057694     -8.170966      0.378047      0.138325
# 4       -95.976963     -9.916990    -11.407312      1.263163     -0.240179
# ...            ...           ...           ...           ...           ...
# 9995   -118.977579     -7.956445    -12.032431     -0.820737     -0.172895
# 9996    -69.982793     -6.807540    -13.433592      1.183742     -0.039127
# 9997    -88.985088     -8.947921     -9.236363      4.393741      0.048864
# 9998   -106.985575     -4.909174    -12.706018      0.151579      0.009777
# 9999   -108.991878     -4.869663    -13.976734      4.085093      0.144073
#
# [10000 rows x 5 columns]

# %%
sns.heatmap(new_input_features.corr(),annot=True)
# Out:
# <Axes: >

# %%
new_data = pd.concat([new_input_features,feature_selected_data[data.columns[-1]]],
                     axis=1)

# %%
new_data
# Out:
#       Input_feat_1  Input_feat_2  Input_feat_3  Input_feat_4  Input_feat_5  \
# 0      -106.985375     -7.981836     -9.555150      3.340004     -0.306328
# 1       -96.979236     -8.012939     -7.923885     -0.560073     -0.162169
# 2      -108.996045     -1.031525     -8.018326      0.386976      0.270885
# 3      -121.985085     -6.057694     -8.170966      0.378047      0.138325
# 4       -95.976963     -9.916990    -11.407312      1.263163     -0.240179
# ...            ...           ...           ...           ...           ...
# 9995   -118.977579     -7.956445    -12.032431     -0.820737     -0.172895
# 9996    -69.982793     -6.807540    -13.433592      1.183742     -0.039127
# 9997    -88.985088     -8.947921     -9.236363      4.393741      0.048864
# 9998   -106.985575     -4.909174    -12.706018      0.151579      0.009777
# 9999   -108.991878     -4.869663    -13.976734      4.085093      0.144073
#
#       Placement
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 9995          1
# 9996          0
# 9997          0
# 9998          0
# 9999          0
#
# [10000 rows x 6 columns]

# %%
plt.hist(new_data[new_data[new_data.columns[-1]] == 1][new_data.columns[0]])
# Out:
# (array([  3.,  22., 101., 362., 572., 236., 208., 109.,  38.,   8.]),
#  array([-157.98374855, -147.7834374 , -137.58312626, -127.38281511,
#         -117.18250397, -106.98219282,  -96.78188168,  -86.58157053,
#          -76.38125939,  -66.18094824,  -55.98063709]),
#  <BarContainer object of 10 artists>)

# %%
new_data[new_data[new_data.columns[-1]] == 1][new_data.columns[0]]
# Out:
# 6      -122.981852
# 7      -110.996007
# 18      -85.982336
# 20     -120.993575
# 23      -77.976418
#            ...
# 9964   -122.993803
# 9978    -83.981477
# 9992   -108.977394
# 9994   -116.992906
# 9995   -118.977579
# Name: Input_feat_1, Length: 1659, dtype: float64

# %%
class GaussianMLEstimatorNN(torch.nn.Module):

    def __init__(self):
        super().__init__()

        self.mu = torch.nn.Parameter(data=torch.tensor([-90.0]))
        self.log_sigma = torch.nn.Parameter(data=torch.tensor([1.0]))

    def forward(self,x):

        g = -self.mu
        h = (x + g)
        i = h**2
        sigma = torch.exp(self.log_sigma)
        j = (-1/(2*sigma**2))*i
        k = torch.exp(j)
        l = (1/(math.sqrt(2*math.pi)*sigma))*k
        f = torch.log(l)

        return -torch.mean(f)

# %%
MLEstimatorNN = GaussianMLEstimatorNN()
optimizer = torch.optim.SGD(params=MLEstimatorNN.parameters(),lr=0.1)
x = torch.tensor(new_data[new_data[new_data.columns[-1]] == 1][new_data.columns[0]].values)
tol = 10**(-8)

# %%
epoch = 0
while True:

    initial_loss_function_value = MLEstimatorNN(x)
    optimizer.zero_grad()
    initial_loss_function_value.backward()
    optimizer.step()
    final_loss_function_value = MLEstimatorNN(x)

    if torch.abs(initial_loss_function_value - final_loss_function_value) < tol:
        break

    epoch += 1

    print("The value of the Gaussian NLL after Epoch # {} is {}".format(epoch,initial_loss_function_value.item()))
# Out:
# The value of the Gaussian NLL after Epoch # 1 is 42.266029066311944
# The value of the Gaussian NLL after Epoch # 2 is 9.888361837868734
# The value of the Gaussian NLL after Epoch # 3 is 9.788363461747323
# The value of the Gaussian NLL after Epoch # 4 is 9.68836625249935
# The value of the Gaussian NLL after Epoch # 5 is 9.588369440294134
# The value of the Gaussian NLL after Epoch # 6 is 9.48837277249125
# The value of the Gaussian NLL after Epoch # 7 is 9.388377625607717
# The value of the Gaussian NLL after Epoch # 8 is 9.28838297958875
# The value of the Gaussian NLL after Epoch # 9 is 9.188389844557458
# The value of the Gaussian NLL after Epoch # 10 is 9.088397513361128
# The value of the Gaussian NLL after Epoch # 11 is 8.988407106843695
# The value of the Gaussian NLL after Epoch # 12 is 8.888419317617034
# The value of the Gaussian NLL after Epoch # 13 is 8.788434341147953
# The value of the Gaussian NLL after Epoch # 14 is 8.688452512690567
# The value of the Gaussian NLL after Epoch # 15 is 8.588474653238611
# The value of the Gaussian NLL after Epoch # 16 is 8.488501756442016
# The value of the Gaussian NLL after Epoch # 17 is 8.388534910334847
# The value of the Gaussian NLL after Epoch # 18 is 8.28857513133778
# The value of the Gaussian NLL after Epoch # 19 is 8.188624409426568
# The value of the Gaussian NLL after Epoch # 20 is 8.088684045199704
# The value of the Gaussian NLL after Epoch # 21 is 7.988757414054066
# The value of the Gaussian NLL after Epoch # 22 is 7.888846940272014
# The value of the Gaussian NLL after Epoch # 23 is 7.788955846618898
# The value of the Gaussian NLL after Epoch # 24 is 7.689089374875511
# The value of the Gaussian NLL after Epoch # 25 is 7.589252173838653
# The value of the Gaussian NLL after Epoch # 26 is 7.489451068838391
# The value of the Gaussian NLL after Epoch # 27 is 7.3896939655039215
# The value of the Gaussian NLL after Epoch # 28 is 7.289990308630742
# The value of the Gaussian NLL after Epoch # 29 is 7.19035191209064
# The value of the Gaussian NLL after Epoch # 30 is 7.090793585946836
# The value of the Gaussian NLL after Epoch # 31 is 6.991332549724378
# The value of the Gaussian NLL after Epoch # 32 is 6.891990450029034
# The value of the Gaussian NLL after Epoch # 33 is 6.7927927534103345
# The value of the Gaussian NLL after Epoch # 34 is 6.693771887161631
# The value of the Gaussian NLL after Epoch # 35 is 6.5949657414744385
# The value of the Gaussian NLL after Epoch # 36 is 6.4964210070877035
# The value of the Gaussian NLL after Epoch # 37 is 6.398194794923214
# The value of the Gaussian NLL after Epoch # 38 is 6.300355203821723
# The value of the Gaussian NLL after Epoch # 39 is 6.2029852681951185
# The value of the Gaussian NLL after Epoch # 40 is 6.106184078106363
# The value of the Gaussian NLL after Epoch # 41 is 6.010071494159956
# The value of the Gaussian NLL after Epoch # 42 is 5.91479106885822
# The value of the Gaussian NLL after Epoch # 43 is 5.820512802478896
# The value of the Gaussian NLL after Epoch # 44 is 5.727438917112287
# The value of the Gaussian NLL after Epoch # 45 is 5.635806603735022
# The value of the Gaussian NLL after Epoch # 46 is 5.5458922853358095
# The value of the Gaussian NLL after Epoch # 47 is 5.458015766074887
# The value of the Gaussian NLL after Epoch # 48 is 5.372541074443068
# The value of the Gaussian NLL after Epoch # 49 is 5.289875901943444
# The value of the Gaussian NLL after Epoch # 50 is 5.210468484636934
# The value of the Gaussian NLL after Epoch # 51 is 5.1347993365577365
# The value of the Gaussian NLL after Epoch # 52 is 5.063367100935558
# The value of the Gaussian NLL after Epoch # 53 is 4.996668191852166
# The value of the Gaussian NLL after Epoch # 54 is 4.935169671994797
# The value of the Gaussian NLL after Epoch # 55 is 4.879276338148627
# The value of the Gaussian NLL after Epoch # 56 is 4.829293450425183
# The value of the Gaussian NLL after Epoch # 57 is 4.785393552995752
# The value of the Gaussian NLL after Epoch # 58 is 4.7475868786761835
# The value of the Gaussian NLL after Epoch # 59 is 4.71570798918866
# The value of the Gaussian NLL after Epoch # 60 is 4.689417936875544
# The value of the Gaussian NLL after Epoch # 61 is 4.668227704219757
# The value of the Gaussian NLL after Epoch # 62 is 4.651537279023045
# The value of the Gaussian NLL after Epoch # 63 is 4.638685485208833
# The value of the Gaussian NLL after Epoch # 64 is 4.6290014609686905
# The value of the Gaussian NLL after Epoch # 65 is 4.62184977554233
# The value of the Gaussian NLL after Epoch # 66 is 4.616662332500205
# The value of the Gaussian NLL after Epoch # 67 is 4.6129569822427205
# The value of the Gaussian NLL after Epoch # 68 is 4.6103424438264575
# The value of the Gaussian NLL after Epoch # 69 is 4.608512711425932
# The value of the Gaussian NLL after Epoch # 70 is 4.607237089646613
# The value of the Gaussian NLL after Epoch # 71 is 4.606345766409104
# The value of the Gaussian NLL after Epoch # 72 is 4.605717499330217
# The value of the Gaussian NLL after Epoch # 73 is 4.605267013070678
# The value of the Gaussian NLL after Epoch # 74 is 4.604935545098622
# The value of the Gaussian NLL after Epoch # 75 is 4.604683025093653
# The value of the Gaussian NLL after Epoch # 76 is 4.604482590383747
# The value of the Gaussian NLL after Epoch # 77 is 4.604316253303063
# The value of the Gaussian NLL after Epoch # 78 is 4.604172110312305
# The value of the Gaussian NLL after Epoch # 79 is 4.604042376650078
# The value of the Gaussian NLL after Epoch # 80 is 4.603922071160841
# The value of the Gaussian NLL after Epoch # 81 is 4.603807995353367
# The value of the Gaussian NLL after Epoch # 82 is 4.603697619229675
# The value of the Gaussian NLL after Epoch # 83 is 4.603589784188354
# The value of the Gaussian NLL after Epoch # 84 is 4.603483558638732
# The value of the Gaussian NLL after Epoch # 85 is 4.603378336899248
# The value of the Gaussian NLL after Epoch # 86 is 4.6032736210079825
# The value of the Gaussian NLL after Epoch # 87 is 4.603169616508229
# The value of the Gaussian NLL after Epoch # 88 is 4.603065733632651
# The value of the Gaussian NLL after Epoch # 89 is 4.602962198972245
# The value of the Gaussian NLL after Epoch # 90 is 4.602858356696789
# The value of the Gaussian NLL after Epoch # 91 is 4.602754914131306
# The value of the Gaussian NLL after Epoch # 92 is 4.6026513287956385
# The value of the Gaussian NLL after Epoch # 93 is 4.602547893454164
# The value of the Gaussian NLL after Epoch # 94 is 4.602444436581894
# The value of the Gaussian NLL after Epoch # 95 is 4.6023410560700455
# The value of the Gaussian NLL after Epoch # 96 is 4.602237510846308
# The value of the Gaussian NLL after Epoch # 97 is 4.602134246342086
# The value of the Gaussian NLL after Epoch # 98 is 4.602030759072013
# The value of the Gaussian NLL after Epoch # 99 is 4.601927413703554
# The value of the Gaussian NLL after Epoch # 100 is 4.601823976065564
# The value of the Gaussian NLL after Epoch # 101 is 4.601720550347299
# The value of the Gaussian NLL after Epoch # 102 is 4.6016172393616035
# The value of the Gaussian NLL after Epoch # 103 is 4.601513875524881
# The value of the Gaussian NLL after Epoch # 104 is 4.601410459862103
# The value of the Gaussian NLL after Epoch # 105 is 4.601307049767387
# The value of the Gaussian NLL after Epoch # 106 is 4.60120370206909
# The value of the Gaussian NLL after Epoch # 107 is 4.601100270996859
# The value of the Gaussian NLL after Epoch # 108 is 4.600996869368586
# The value of the Gaussian NLL after Epoch # 109 is 4.600893173523572
# The value of the Gaussian NLL after Epoch # 110 is 4.60078955267028
# The value of the Gaussian NLL after Epoch # 111 is 4.600685793253485
# The value of the Gaussian NLL after Epoch # 112 is 4.600582154196338
# The value of the Gaussian NLL after Epoch # 113 is 4.60047856800346
# The value of the Gaussian NLL after Epoch # 114 is 4.600374899797374
# The value of the Gaussian NLL after Epoch # 115 is 4.600271194614167
# The value of the Gaussian NLL after Epoch # 116 is 4.600167497501349
# The value of the Gaussian NLL after Epoch # 117 is 4.600063864696829
# The value of the Gaussian NLL after Epoch # 118 is 4.599960127529219
# The value of the Gaussian NLL after Epoch # 119 is 4.599856477142947
# The value of the Gaussian NLL after Epoch # 120 is 4.599752812481553
# The value of the Gaussian NLL after Epoch # 121 is 4.599649054781321
# The value of the Gaussian NLL after Epoch # 122 is 4.599545395165488
# The value of the Gaussian NLL after Epoch # 123 is 4.599441676216197
# The value of the Gaussian NLL after Epoch # 124 is 4.59933797662661
# The value of the Gaussian NLL after Epoch # 125 is 4.599234262706404
# The value of the Gaussian NLL after Epoch # 126 is 4.5991305007932075
# The value of the Gaussian NLL after Epoch # 127 is 4.599026859238347
# The value of the Gaussian NLL after Epoch # 128 is 4.598923169680375
# The value of the Gaussian NLL after Epoch # 129 is 4.598819319830939
# The value of the Gaussian NLL after Epoch # 130 is 4.5987156689413675
# The value of the Gaussian NLL after Epoch # 131 is 4.598612003718785
# The value of the Gaussian NLL after Epoch # 132 is 4.598508133234962
# The value of the Gaussian NLL after Epoch # 133 is 4.5984044393894274
# The value of the Gaussian NLL after Epoch # 134 is 4.598300686208547
# The value of the Gaussian NLL after Epoch # 135 is 4.59819703097407
# The value of the Gaussian NLL after Epoch # 136 is 4.598093282788091
# The value of the Gaussian NLL after Epoch # 137 is 4.5979895310156325
# The value of the Gaussian NLL after Epoch # 138 is 4.5978857427662625
# The value of the Gaussian NLL after Epoch # 139 is 4.597782018839368
# The value of the Gaussian NLL after Epoch # 140 is 4.597678201996863
# The value of the Gaussian NLL after Epoch # 141 is 4.597574449485368
# The value of the Gaussian NLL after Epoch # 142 is 4.597470648229265
# The value of the Gaussian NLL after Epoch # 143 is 4.597366855639422
# The value of the Gaussian NLL after Epoch # 144 is 4.597263082313475
# The value of the Gaussian NLL after Epoch # 145 is 4.597159261161901
# The value of the Gaussian NLL after Epoch # 146 is 4.597055615412566
# The value of the Gaussian NLL after Epoch # 147 is 4.596951765691005
# The value of the Gaussian NLL after Epoch # 148 is 4.596847923698019
# The value of the Gaussian NLL after Epoch # 149 is 4.596744156415889
# The value of the Gaussian NLL after Epoch # 150 is 4.596640319366739
# The value of the Gaussian NLL after Epoch # 151 is 4.596536580114203
# The value of the Gaussian NLL after Epoch # 152 is 4.596432793091796
# The value of the Gaussian NLL after Epoch # 153 is 4.596328990527264
# The value of the Gaussian NLL after Epoch # 154 is 4.596225096414284
# The value of the Gaussian NLL after Epoch # 155 is 4.596121298732858
# The value of the Gaussian NLL after Epoch # 156 is 4.5960175652799675
# The value of the Gaussian NLL after Epoch # 157 is 4.595913717147537
# The value of the Gaussian NLL after Epoch # 158 is 4.59580983293939
# The value of the Gaussian NLL after Epoch # 159 is 4.595706044986038
# The value of the Gaussian NLL after Epoch # 160 is 4.595602266035607
# The value of the Gaussian NLL after Epoch # 161 is 4.595498404409034
# The value of the Gaussian NLL after Epoch # 162 is 4.595394563508019
# The value of the Gaussian NLL after Epoch # 163 is 4.595290706748759
# The value of the Gaussian NLL after Epoch # 164 is 4.59518679227014
# The value of the Gaussian NLL after Epoch # 165 is 4.595082973777053
# The value of the Gaussian NLL after Epoch # 166 is 4.594979131012248
# The value of the Gaussian NLL after Epoch # 167 is 4.594875283959296
# The value of the Gaussian NLL after Epoch # 168 is 4.594771467733772
# The value of the Gaussian NLL after Epoch # 169 is 4.5946675371265
# The value of the Gaussian NLL after Epoch # 170 is 4.594563668907971
# The value of the Gaussian NLL after Epoch # 171 is 4.594459788312094
# The value of the Gaussian NLL after Epoch # 172 is 4.594355924919837
# The value of the Gaussian NLL after Epoch # 173 is 4.594252092365263
# The value of the Gaussian NLL after Epoch # 174 is 4.594148190651868
# The value of the Gaussian NLL after Epoch # 175 is 4.59404425114358
# The value of the Gaussian NLL after Epoch # 176 is 4.593940475814908
# The value of the Gaussian NLL after Epoch # 177 is 4.593836250062676
# The value of the Gaussian NLL after Epoch # 178 is 4.593732088493349
# The value of the Gaussian NLL after Epoch # 179 is 4.593628012576267
# The value of the Gaussian NLL after Epoch # 180 is 4.593523777349718
# The value of the Gaussian NLL after Epoch # 181 is 4.593419639594317
# The value of the Gaussian NLL after Epoch # 182 is 4.593315554146336
# The value of the Gaussian NLL after Epoch # 183 is 4.593211273862322
# The value of the Gaussian NLL after Epoch # 184 is 4.593107190777255
# The value of the Gaussian NLL after Epoch # 185 is 4.5930030292196395
# The value of the Gaussian NLL after Epoch # 186 is 4.5928988177499654
# The value of the Gaussian NLL after Epoch # 187 is 4.592794646593203
# The value of the Gaussian NLL after Epoch # 188 is 4.592690617903176
# The value of the Gaussian NLL after Epoch # 189 is 4.592586351645785
# The value of the Gaussian NLL after Epoch # 190 is 4.592482104344153
# The value of the Gaussian NLL after Epoch # 191 is 4.592377921144646
# The value of the Gaussian NLL after Epoch # 192 is 4.592273856520081
# The value of the Gaussian NLL after Epoch # 193 is 4.59216959958803
# The value of the Gaussian NLL after Epoch # 194 is 4.592065349627057
# The value of the Gaussian NLL after Epoch # 195 is 4.591961208906856
# The value of the Gaussian NLL after Epoch # 196 is 4.591857008736827
# The value of the Gaussian NLL after Epoch # 197 is 4.59175271594139
# The value of the Gaussian NLL after Epoch # 198 is 4.591648586746686
# The value of the Gaussian NLL after Epoch # 199 is 4.591544343759995
# The value of the Gaussian NLL after Epoch # 200 is 4.591440107661498
# The value of the Gaussian NLL after Epoch # 201 is 4.5913359024716405
# The value of the Gaussian NLL after Epoch # 202 is 4.5912316378415285
# The value of the Gaussian NLL after Epoch # 203 is 4.591127437279401
# The value of the Gaussian NLL after Epoch # 204 is 4.591023210406819
# The value of the Gaussian NLL after Epoch # 205 is 4.590918969271759
# The value of the Gaussian NLL after Epoch # 206 is 4.590814780115188
# The value of the Gaussian NLL after Epoch # 207 is 4.590710543577861
# The value of the Gaussian NLL after Epoch # 208 is 4.5906062144941195
# The value of the Gaussian NLL after Epoch # 209 is 4.5905019825683
# The value of the Gaussian NLL after Epoch # 210 is 4.5903976581100245
# The value of the Gaussian NLL after Epoch # 211 is 4.590293496953797
# The value of the Gaussian NLL after Epoch # 212 is 4.590189177102494
# The value of the Gaussian NLL after Epoch # 213 is 4.590084876097704
# The value of the Gaussian NLL after Epoch # 214 is 4.589980705258028
# The value of the Gaussian NLL after Epoch # 215 is 4.5898764088463455
# The value of the Gaussian NLL after Epoch # 216 is 4.589772173022041
# The value of the Gaussian NLL after Epoch # 217 is 4.58966788117852
# The value of the Gaussian NLL after Epoch # 218 is 4.5895636081516304
# The value of the Gaussian NLL after Epoch # 219 is 4.58945936256946
# The value of the Gaussian NLL after Epoch # 220 is 4.58935508189462
# The value of the Gaussian NLL after Epoch # 221 is 4.589250766184166
# The value of the Gaussian NLL after Epoch # 222 is 4.589146465629834
# The value of the Gaussian NLL after Epoch # 223 is 4.589042142269755
# The value of the Gaussian NLL after Epoch # 224 is 4.588937846209131
# The value of the Gaussian NLL after Epoch # 225 is 4.588833527397374
# The value of the Gaussian NLL after Epoch # 226 is 4.588729235826035
# The value of the Gaussian NLL after Epoch # 227 is 4.588624888586998
# The value of the Gaussian NLL after Epoch # 228 is 4.588520667436046
# The value of the Gaussian NLL after Epoch # 229 is 4.588416312459589
# The value of the Gaussian NLL after Epoch # 230 is 4.588311988529257
# The value of the Gaussian NLL after Epoch # 231 is 4.588207658755094
# The value of the Gaussian NLL after Epoch # 232 is 4.588103335382454
# The value of the Gaussian NLL after Epoch # 233 is 4.587999034722655
# The value of the Gaussian NLL after Epoch # 234 is 4.5878947158155
# The value of the Gaussian NLL after Epoch # 235 is 4.58779030449583
# The value of the Gaussian NLL after Epoch # 236 is 4.587685981812227
# The value of the Gaussian NLL after Epoch # 237 is 4.587581653131486
# The value of the Gaussian NLL after Epoch # 238 is 4.5874772691613925
# The value of the Gaussian NLL after Epoch # 239 is 4.58737293258004
# The value of the Gaussian NLL after Epoch # 240 is 4.587268627022173
# The value of the Gaussian NLL after Epoch # 241 is 4.58716423339548
# The value of the Gaussian NLL after Epoch # 242 is 4.587059854160608
# The value of the Gaussian NLL after Epoch # 243 is 4.586955526434713
# The value of the Gaussian NLL after Epoch # 244 is 4.586851229750473
# The value of the Gaussian NLL after Epoch # 245 is 4.586746754610193
# The value of the Gaussian NLL after Epoch # 246 is 4.5866423842553905
# The value of the Gaussian NLL after Epoch # 247 is 4.586537999696653
# The value of the Gaussian NLL after Epoch # 248 is 4.586433666597256
# The value of the Gaussian NLL after Epoch # 249 is 4.586328986770887
# The value of the Gaussian NLL after Epoch # 250 is 4.586224456851007
# The value of the Gaussian NLL after Epoch # 251 is 4.5861196456211
# The value of the Gaussian NLL after Epoch # 252 is 4.58601507480214
# The value of the Gaussian NLL after Epoch # 253 is 4.585910444471928
# The value of the Gaussian NLL after Epoch # 254 is 4.585805807695958
# The value of the Gaussian NLL after Epoch # 255 is 4.585701189445089
# The value of the Gaussian NLL after Epoch # 256 is 4.585596446092785
# The value of the Gaussian NLL after Epoch # 257 is 4.58549176658125
# The value of the Gaussian NLL after Epoch # 258 is 4.585387171119064
# The value of the Gaussian NLL after Epoch # 259 is 4.5852824833424215
# The value of the Gaussian NLL after Epoch # 260 is 4.585177781327106
# The value of the Gaussian NLL after Epoch # 261 is 4.585073175867728
# The value of the Gaussian NLL after Epoch # 262 is 4.584968510853489
# The value of the Gaussian NLL after Epoch # 263 is 4.584863831601295
# The value of the Gaussian NLL after Epoch # 264 is 4.584759072686037
# The value of the Gaussian NLL after Epoch # 265 is 4.584654463130972
# The value of the Gaussian NLL after Epoch # 266 is 4.584549741214365
# The value of the Gaussian NLL after Epoch # 267 is 4.58444502516846
# The value of the Gaussian NLL after Epoch # 268 is 4.584340372914172
# The value of the Gaussian NLL after Epoch # 269 is 4.584235739120185
# The value of the Gaussian NLL after Epoch # 270 is 4.584130947742095
# The value of the Gaussian NLL after Epoch # 271 is 4.584026272860563
# The value of the Gaussian NLL after Epoch # 272 is 4.583921596423253
# The value of the Gaussian NLL after Epoch # 273 is 4.583816925763546
# The value of the Gaussian NLL after Epoch # 274 is 4.583712142936467
# The value of the Gaussian NLL after Epoch # 275 is 4.583607411222821
# The value of the Gaussian NLL after Epoch # 276 is 4.583502717884956
# The value of the Gaussian NLL after Epoch # 277 is 4.583398035752791
# The value of the Gaussian NLL after Epoch # 278 is 4.583293281372256
# The value of the Gaussian NLL after Epoch # 279 is 4.583188512799999
# The value of the Gaussian NLL after Epoch # 280 is 4.583083762653244
# The value of the Gaussian NLL after Epoch # 281 is 4.582979076272543
# The value of the Gaussian NLL after Epoch # 282 is 4.582874375705249
# The value of the Gaussian NLL after Epoch # 283 is 4.5827696156049775
# The value of the Gaussian NLL after Epoch # 284 is 4.582664873913286
# The value of the Gaussian NLL after Epoch # 285 is 4.5825601506191305
# The value of the Gaussian NLL after Epoch # 286 is 4.582455302648887
# The value of the Gaussian NLL after Epoch # 287 is 4.582350655646938
# The value of the Gaussian NLL after Epoch # 288 is 4.5822457467807425
# The value of the Gaussian NLL after Epoch # 289 is 4.582141038802097
# The value of the Gaussian NLL after Epoch # 290 is 4.5820363294351365
# The value of the Gaussian NLL after Epoch # 291 is 4.581931508278111
# The value of the Gaussian NLL after Epoch # 292 is 4.58182679023481
# The value of the Gaussian NLL after Epoch # 293 is 4.5817220451298235
# The value of the Gaussian NLL after Epoch # 294 is 4.581617168629301
# The value of the Gaussian NLL after Epoch # 295 is 4.581512355884008
# The value of the Gaussian NLL after Epoch # 296 is 4.581407633234501
# The value of the Gaussian NLL after Epoch # 297 is 4.581302889667436
# The value of the Gaussian NLL after Epoch # 298 is 4.581198131947529
# The value of the Gaussian NLL after Epoch # 299 is 4.581093178528834
# The value of the Gaussian NLL after Epoch # 300 is 4.5809884640988
# The value of the Gaussian NLL after Epoch # 301 is 4.580883625145856
# The value of the Gaussian NLL after Epoch # 302 is 4.580778797899075
# The value of the Gaussian NLL after Epoch # 303 is 4.580673963088133
# The value of the Gaussian NLL after Epoch # 304 is 4.580569237356796
# The value of the Gaussian NLL after Epoch # 305 is 4.580464439102006
# The value of the Gaussian NLL after Epoch # 306 is 4.580359652621309
# The value of the Gaussian NLL after Epoch # 307 is 4.58025474822277
# The value of the Gaussian NLL after Epoch # 308 is 4.5801499723401236
# The value of the Gaussian NLL after Epoch # 309 is 4.580045098056151
# The value of the Gaussian NLL after Epoch # 310 is 4.57994029387295
# The value of the Gaussian NLL after Epoch # 311 is 4.579835417109128
# The value of the Gaussian NLL after Epoch # 312 is 4.5797306106743205
# The value of the Gaussian NLL after Epoch # 313 is 4.57962581580636
# The value of the Gaussian NLL after Epoch # 314 is 4.579520968105251
# The value of the Gaussian NLL after Epoch # 315 is 4.579416177313714
# The value of the Gaussian NLL after Epoch # 316 is 4.579311275272644
# The value of the Gaussian NLL after Epoch # 317 is 4.579206410762637
# The value of the Gaussian NLL after Epoch # 318 is 4.579101577533732
# The value of the Gaussian NLL after Epoch # 319 is 4.578996684742445
# The value of the Gaussian NLL after Epoch # 320 is 4.578891739344645
# The value of the Gaussian NLL after Epoch # 321 is 4.578786993088047
# The value of the Gaussian NLL after Epoch # 322 is 4.578682012513742
# The value of the Gaussian NLL after Epoch # 323 is 4.578577160219933
# The value of the Gaussian NLL after Epoch # 324 is 4.578472403852743
# The value of the Gaussian NLL after Epoch # 325 is 4.578367445553865
# The value of the Gaussian NLL after Epoch # 326 is 4.578262336082889
# The value of the Gaussian NLL after Epoch # 327 is 4.578157167036757
# The value of the Gaussian NLL after Epoch # 328 is 4.57805209387702
# The value of the Gaussian NLL after Epoch # 329 is 4.577946896581084
# The value of the Gaussian NLL after Epoch # 330 is 4.577841749715892
# The value of the Gaussian NLL after Epoch # 331 is 4.577736556467508
# The value of the Gaussian NLL after Epoch # 332 is 4.5776314839875205
# The value of the Gaussian NLL after Epoch # 333 is 4.577526332820299
# The value of the Gaussian NLL after Epoch # 334 is 4.577421199737966
# The value of the Gaussian NLL after Epoch # 335 is 4.577316084729813
# The value of the Gaussian NLL after Epoch # 336 is 4.577210877867222
# The value of the Gaussian NLL after Epoch # 337 is 4.577105766766631
# The value of the Gaussian NLL after Epoch # 338 is 4.577000563826887
# The value of the Gaussian NLL after Epoch # 339 is 4.576895346748516
# The value of the Gaussian NLL after Epoch # 340 is 4.576790212140973
# The value of the Gaussian NLL after Epoch # 341 is 4.576685063373456
# The value of the Gaussian NLL after Epoch # 342 is 4.576579868269228
# The value of the Gaussian NLL after Epoch # 343 is 4.576474723397126
# The value of the Gaussian NLL after Epoch # 344 is 4.576369486727839
# The value of the Gaussian NLL after Epoch # 345 is 4.576264281415007
# The value of the Gaussian NLL after Epoch # 346 is 4.576159112984688
# The value of the Gaussian NLL after Epoch # 347 is 4.576053975893526
# The value of the Gaussian NLL after Epoch # 348 is 4.5759486827443085
# The value of the Gaussian NLL after Epoch # 349 is 4.575843613832318
# The value of the Gaussian NLL after Epoch # 350 is 4.5757382791214045
# The value of the Gaussian NLL after Epoch # 351 is 4.575633104321386
# The value of the Gaussian NLL after Epoch # 352 is 4.575527947514857
# The value of the Gaussian NLL after Epoch # 353 is 4.575422680243266
# The value of the Gaussian NLL after Epoch # 354 is 4.57531749520851
# The value of the Gaussian NLL after Epoch # 355 is 4.575212250562438
# The value of the Gaussian NLL after Epoch # 356 is 4.575107101499398
# The value of the Gaussian NLL after Epoch # 357 is 4.575001833887371
# The value of the Gaussian NLL after Epoch # 358 is 4.574896579000918
# The value of the Gaussian NLL after Epoch # 359 is 4.574791387606992
# The value of the Gaussian NLL after Epoch # 360 is 4.574686096273267
# The value of the Gaussian NLL after Epoch # 361 is 4.574580940800302
# The value of the Gaussian NLL after Epoch # 362 is 4.5744755891701425
# The value of the Gaussian NLL after Epoch # 363 is 4.574370378561673
# The value of the Gaussian NLL after Epoch # 364 is 4.574265135285696
# The value of the Gaussian NLL after Epoch # 365 is 4.5741598829896395
# The value of the Gaussian NLL after Epoch # 366 is 4.574054707630643
# The value of the Gaussian NLL after Epoch # 367 is 4.573949440637346
# The value of the Gaussian NLL after Epoch # 368 is 4.573844164549843
# The value of the Gaussian NLL after Epoch # 369 is 4.573738842347423
# The value of the Gaussian NLL after Epoch # 370 is 4.573633698041085
# The value of the Gaussian NLL after Epoch # 371 is 4.573528329184355
# The value of the Gaussian NLL after Epoch # 372 is 4.573423165295146
# The value of the Gaussian NLL after Epoch # 373 is 4.57331788269899
# The value of the Gaussian NLL after Epoch # 374 is 4.573212535641314
# The value of the Gaussian NLL after Epoch # 375 is 4.573107320789622
# The value of the Gaussian NLL after Epoch # 376 is 4.573001932043411
# The value of the Gaussian NLL after Epoch # 377 is 4.572896720965215
# The value of the Gaussian NLL after Epoch # 378 is 4.572791386349727
# The value of the Gaussian NLL after Epoch # 379 is 4.572686128759775
# The value of the Gaussian NLL after Epoch # 380 is 4.572580829875522
# The value of the Gaussian NLL after Epoch # 381 is 4.572475484989447
# The value of the Gaussian NLL after Epoch # 382 is 4.57237024907285
# The value of the Gaussian NLL after Epoch # 383 is 4.572264862436718
# The value of the Gaussian NLL after Epoch # 384 is 4.572159557456805
# The value of the Gaussian NLL after Epoch # 385 is 4.572054311280171
# The value of the Gaussian NLL after Epoch # 386 is 4.571948946272252
# The value of the Gaussian NLL after Epoch # 387 is 4.571843630979581
# The value of the Gaussian NLL after Epoch # 388 is 4.571738342687437
# The value of the Gaussian NLL after Epoch # 389 is 4.571633063033988
# The value of the Gaussian NLL after Epoch # 390 is 4.571527701130474
# The value of the Gaussian NLL after Epoch # 391 is 4.5714223478027245
# The value of the Gaussian NLL after Epoch # 392 is 4.571317025989042
# The value of the Gaussian NLL after Epoch # 393 is 4.571211612711805
# The value of the Gaussian NLL after Epoch # 394 is 4.571106358329329
# The value of the Gaussian NLL after Epoch # 395 is 4.571001058051288
# The value of the Gaussian NLL after Epoch # 396 is 4.570895729971788
# The value of the Gaussian NLL after Epoch # 397 is 4.570790288112339
# The value of the Gaussian NLL after Epoch # 398 is 4.570684963794826
# The value of the Gaussian NLL after Epoch # 399 is 4.570579625433029
# The value of the Gaussian NLL after Epoch # 400 is 4.570474273036763
# The value of the Gaussian NLL after Epoch # 401 is 4.5703689384048936
# The value of the Gaussian NLL after Epoch # 402 is 4.57026354415246
# The value of the Gaussian NLL after Epoch # 403 is 4.570158213247698
# The value of the Gaussian NLL after Epoch # 404 is 4.57005278684122
# The value of the Gaussian NLL after Epoch # 405 is 4.5699474596932514
# The value of the Gaussian NLL after Epoch # 406 is 4.569842182040705
# The value of the Gaussian NLL after Epoch # 407 is 4.569736519720304
# The value of the Gaussian NLL after Epoch # 408 is 4.569630857230754
# The value of the Gaussian NLL after Epoch # 409 is 4.5695252898141785
# The value of the Gaussian NLL after Epoch # 410 is 4.569419617165761
# The value of the Gaussian NLL after Epoch # 411 is 4.5693140078344285
# The value of the Gaussian NLL after Epoch # 412 is 4.569208311085514
# The value of the Gaussian NLL after Epoch # 413 is 4.569102709324735
# The value of the Gaussian NLL after Epoch # 414 is 4.568997047893287
# The value of the Gaussian NLL after Epoch # 415 is 4.568891404107712
# The value of the Gaussian NLL after Epoch # 416 is 4.568785714580732
# The value of the Gaussian NLL after Epoch # 417 is 4.568680137751656
# The value of the Gaussian NLL after Epoch # 418 is 4.568574483499082
# The value of the Gaussian NLL after Epoch # 419 is 4.568468783541576
# The value of the Gaussian NLL after Epoch # 420 is 4.568363118929862
# The value of the Gaussian NLL after Epoch # 421 is 4.568257376960859
# The value of the Gaussian NLL after Epoch # 422 is 4.568151793205203
# The value of the Gaussian NLL after Epoch # 423 is 4.568046118125573
# The value of the Gaussian NLL after Epoch # 424 is 4.567940443014149
# The value of the Gaussian NLL after Epoch # 425 is 4.56783483477673
# The value of the Gaussian NLL after Epoch # 426 is 4.567729086001804
# The value of the Gaussian NLL after Epoch # 427 is 4.567623372444857
# The value of the Gaussian NLL after Epoch # 428 is 4.567517722116235
# The value of the Gaussian NLL after Epoch # 429 is 4.56741205776661
# The value of the Gaussian NLL after Epoch # 430 is 4.567306333760857
# The value of the Gaussian NLL after Epoch # 431 is 4.567200609808984
# The value of the Gaussian NLL after Epoch # 432 is 4.567095033234376
# The value of the Gaussian NLL after Epoch # 433 is 4.5669892672040415
# The value of the Gaussian NLL after Epoch # 434 is 4.566883613471718
# The value of the Gaussian NLL after Epoch # 435 is 4.5667779141595055
# The value of the Gaussian NLL after Epoch # 436 is 4.5666720638837
# The value of the Gaussian NLL after Epoch # 437 is 4.566566434559127
# The value of the Gaussian NLL after Epoch # 438 is 4.5664606617009875
# The value of the Gaussian NLL after Epoch # 439 is 4.5663550325655
# The value of the Gaussian NLL after Epoch # 440 is 4.566249312229808
# The value of the Gaussian NLL after Epoch # 441 is 4.566143560527643
# The value of the Gaussian NLL after Epoch # 442 is 4.566037815449657
# The value of the Gaussian NLL after Epoch # 443 is 4.565932087863762
# The value of the Gaussian NLL after Epoch # 444 is 4.565826343095544
# The value of the Gaussian NLL after Epoch # 445 is 4.565720681989077
# The value of the Gaussian NLL after Epoch # 446 is 4.5656149722393975
# The value of the Gaussian NLL after Epoch # 447 is 4.565509185557793
# The value of the Gaussian NLL after Epoch # 448 is 4.565403450962165
# The value of the Gaussian NLL after Epoch # 449 is 4.5652977510952635
# The value of the Gaussian NLL after Epoch # 450 is 4.565192048397961
# The value of the Gaussian NLL after Epoch # 451 is 4.565086223151688
# The value of the Gaussian NLL after Epoch # 452 is 4.564980512750079
# The value of the Gaussian NLL after Epoch # 453 is 4.564874802581381
# The value of the Gaussian NLL after Epoch # 454 is 4.564768921251862
# The value of the Gaussian NLL after Epoch # 455 is 4.564663168892206
# The value of the Gaussian NLL after Epoch # 456 is 4.564557402549884
# The value of the Gaussian NLL after Epoch # 457 is 4.564451605099404
# The value of the Gaussian NLL after Epoch # 458 is 4.564345873653799
# The value of the Gaussian NLL after Epoch # 459 is 4.564240128229076
# The value of the Gaussian NLL after Epoch # 460 is 4.564134320349914
# The value of the Gaussian NLL after Epoch # 461 is 4.56402853270549
# The value of the Gaussian NLL after Epoch # 462 is 4.563922836824271
# The value of the Gaussian NLL after Epoch # 463 is 4.563817115395846
# The value of the Gaussian NLL after Epoch # 464 is 4.563711220447786
# The value of the Gaussian NLL after Epoch # 465 is 4.563605502476906
# The value of the Gaussian NLL after Epoch # 466 is 4.5634995993952545
# The value of the Gaussian NLL after Epoch # 467 is 4.563393853501765
# The value of the Gaussian NLL after Epoch # 468 is 4.563288091052502
# The value of the Gaussian NLL after Epoch # 469 is 4.5631821631721285
# The value of the Gaussian NLL after Epoch # 470 is 4.563076438123853
# The value of the Gaussian NLL after Epoch # 471 is 4.5629706677985675
# The value of the Gaussian NLL after Epoch # 472 is 4.562864900451177
# The value of the Gaussian NLL after Epoch # 473 is 4.562759022745722
# The value of the Gaussian NLL after Epoch # 474 is 4.5626532588509505
# The value of the Gaussian NLL after Epoch # 475 is 4.562547403988958
# The value of the Gaussian NLL after Epoch # 476 is 4.562441580930897
# The value of the Gaussian NLL after Epoch # 477 is 4.562335729513531
# The value of the Gaussian NLL after Epoch # 478 is 4.56222990754791
# The value of the Gaussian NLL after Epoch # 479 is 4.562124167871659
# The value of the Gaussian NLL after Epoch # 480 is 4.5620183060005965
# The value of the Gaussian NLL after Epoch # 481 is 4.561912461484647
# The value of the Gaussian NLL after Epoch # 482 is 4.5618066343140695
# The value of the Gaussian NLL after Epoch # 483 is 4.5617007619937375
# The value of the Gaussian NLL after Epoch # 484 is 4.561594923754963
# The value of the Gaussian NLL after Epoch # 485 is 4.561489021456775
# The value of the Gaussian NLL after Epoch # 486 is 4.561383232408823
# The value of the Gaussian NLL after Epoch # 487 is 4.561277398238355
# The value of the Gaussian NLL after Epoch # 488 is 4.561171504434897
# The value of the Gaussian NLL after Epoch # 489 is 4.561065627958149
# The value of the Gaussian NLL after Epoch # 490 is 4.560959845748433
# The value of the Gaussian NLL after Epoch # 491 is 4.5608539727013575
# The value of the Gaussian NLL after Epoch # 492 is 4.5607480857819205
# The value of the Gaussian NLL after Epoch # 493 is 4.56064221617688
# The value of the Gaussian NLL after Epoch # 494 is 4.560536395046587
# The value of the Gaussian NLL after Epoch # 495 is 4.560430311771697
# The value of the Gaussian NLL after Epoch # 496 is 4.560324137691948
# The value of the Gaussian NLL after Epoch # 497 is 4.560217980898384
# The value of the Gaussian NLL after Epoch # 498 is 4.56011185600557
# The value of the Gaussian NLL after Epoch # 499 is 4.560005658729216
# The value of the Gaussian NLL after Epoch # 500 is 4.559899555574799
# The value of the Gaussian NLL after Epoch # 501 is 4.5597934384976435
# The value of the Gaussian NLL after Epoch # 502 is 4.559687338625122
# The value of the Gaussian NLL after Epoch # 503 is 4.55958127061366
# The value of the Gaussian NLL after Epoch # 504 is 4.5594750660399495
# The value of the Gaussian NLL after Epoch # 505 is 4.559368955555634
# The value of the Gaussian NLL after Epoch # 506 is 4.5592627085190545
# The value of the Gaussian NLL after Epoch # 507 is 4.559156663504522
# The value of the Gaussian NLL after Epoch # 508 is 4.559050465555057
# The value of the Gaussian NLL after Epoch # 509 is 4.558944207947857
# The value of the Gaussian NLL after Epoch # 510 is 4.558838183375866
# The value of the Gaussian NLL after Epoch # 511 is 4.55873197486973
# The value of the Gaussian NLL after Epoch # 512 is 4.558625830922769
# The value of the Gaussian NLL after Epoch # 513 is 4.558519656781547
# The value of the Gaussian NLL after Epoch # 514 is 4.558413391947632
# The value of the Gaussian NLL after Epoch # 515 is 4.558307314228967
# The value of the Gaussian NLL after Epoch # 516 is 4.558201083745561
# The value of the Gaussian NLL after Epoch # 517 is 4.5580949029064515
# The value of the Gaussian NLL after Epoch # 518 is 4.5579887687536
# The value of the Gaussian NLL after Epoch # 519 is 4.557882527708664
# The value of the Gaussian NLL after Epoch # 520 is 4.5577764292118745
# The value of the Gaussian NLL after Epoch # 521 is 4.557670253442206
# The value of the Gaussian NLL after Epoch # 522 is 4.557564125796929
# The value of the Gaussian NLL after Epoch # 523 is 4.557457845542127
# The value of the Gaussian NLL after Epoch # 524 is 4.5573516456782555
# The value of the Gaussian NLL after Epoch # 525 is 4.557245445504827
# The value of the Gaussian NLL after Epoch # 526 is 4.5571391411246305
# The value of the Gaussian NLL after Epoch # 527 is 4.557033006155702
# The value of the Gaussian NLL after Epoch # 528 is 4.556926766908047
# The value of the Gaussian NLL after Epoch # 529 is 4.5568205584272805
# The value of the Gaussian NLL after Epoch # 530 is 4.556714399143631
# The value of the Gaussian NLL after Epoch # 531 is 4.556608086246214
# The value of the Gaussian NLL after Epoch # 532 is 4.556501868330345
# The value of the Gaussian NLL after Epoch # 533 is 4.556395790048704
# The value of the Gaussian NLL after Epoch # 534 is 4.556289466641283
# The value of the Gaussian NLL after Epoch # 535 is 4.556183284997385
# The value of the Gaussian NLL after Epoch # 536 is 4.556077058587022
# The value of the Gaussian NLL after Epoch # 537 is 4.555970817336969
# The value of the Gaussian NLL after Epoch # 538 is 4.555864625020818
# The value of the Gaussian NLL after Epoch # 539 is 4.555758387031979
# The value of the Gaussian NLL after Epoch # 540 is 4.555652136178166
# The value of the Gaussian NLL after Epoch # 541 is 4.555545949102877
# The value of the Gaussian NLL after Epoch # 542 is 4.555439700567763
# The value of the Gaussian NLL after Epoch # 543 is 4.555333361572269
# The value of the Gaussian NLL after Epoch # 544 is 4.555227178867686
# The value of the Gaussian NLL after Epoch # 545 is 4.555120998150468
# The value of the Gaussian NLL after Epoch # 546 is 4.555014571982565
# The value of the Gaussian NLL after Epoch # 547 is 4.5549083944540385
# The value of the Gaussian NLL after Epoch # 548 is 4.554802110637644
# The value of the Gaussian NLL after Epoch # 549 is 4.554695874642916
# The value of the Gaussian NLL after Epoch # 550 is 4.554589609782484
# The value of the Gaussian NLL after Epoch # 551 is 4.554483376296789
# The value of the Gaussian NLL after Epoch # 552 is 4.554377053050359
# The value of the Gaussian NLL after Epoch # 553 is 4.55427082344718
# The value of the Gaussian NLL after Epoch # 554 is 4.554164564362102
# The value of the Gaussian NLL after Epoch # 555 is 4.554058184694824
# The value of the Gaussian NLL after Epoch # 556 is 4.553951975280512
# The value of the Gaussian NLL after Epoch # 557 is 4.553845706207649
# The value of the Gaussian NLL after Epoch # 558 is 4.553739407723917
# The value of the Gaussian NLL after Epoch # 559 is 4.5536332033383955
# The value of the Gaussian NLL after Epoch # 560 is 4.553526862207229
# The value of the Gaussian NLL after Epoch # 561 is 4.553420522921322
# The value of the Gaussian NLL after Epoch # 562 is 4.553314262046889
# The value of the Gaussian NLL after Epoch # 563 is 4.553207971439326
# The value of the Gaussian NLL after Epoch # 564 is 4.55310166786981
# The value of the Gaussian NLL after Epoch # 565 is 4.5529953656968205
# The value of the Gaussian NLL after Epoch # 566 is 4.552889049768669
# The value of the Gaussian NLL after Epoch # 567 is 4.552782812166943
# The value of the Gaussian NLL after Epoch # 568 is 4.552676422575395
# The value of the Gaussian NLL after Epoch # 569 is 4.552570065445912
# The value of the Gaussian NLL after Epoch # 570 is 4.5524638479570445
# The value of the Gaussian NLL after Epoch # 571 is 4.552357540143813
# The value of the Gaussian NLL after Epoch # 572 is 4.552251157266942
# The value of the Gaussian NLL after Epoch # 573 is 4.5521449291786045
# The value of the Gaussian NLL after Epoch # 574 is 4.552038580154078
# The value of the Gaussian NLL after Epoch # 575 is 4.5519322021526785
# The value of the Gaussian NLL after Epoch # 576 is 4.551825917592045
# The value of the Gaussian NLL after Epoch # 577 is 4.551719588671244
# The value of the Gaussian NLL after Epoch # 578 is 4.55161324603895
# The value of the Gaussian NLL after Epoch # 579 is 4.5515069356372795
# The value of the Gaussian NLL after Epoch # 580 is 4.551400550291361
# The value of the Gaussian NLL after Epoch # 581 is 4.5512942124473454
# The value of the Gaussian NLL after Epoch # 582 is 4.551187830298687
# The value of the Gaussian NLL after Epoch # 583 is 4.5510815109590235
# The value of the Gaussian NLL after Epoch # 584 is 4.550975147264849
# The value of the Gaussian NLL after Epoch # 585 is 4.5508687240560155
# The value of the Gaussian NLL after Epoch # 586 is 4.550762470589861
# The value of the Gaussian NLL after Epoch # 587 is 4.55065620339903
# The value of the Gaussian NLL after Epoch # 588 is 4.550549784913636
# The value of the Gaussian NLL after Epoch # 589 is 4.550443383307425
# The value of the Gaussian NLL after Epoch # 590 is 4.550336968030747
# The value of the Gaussian NLL after Epoch # 591 is 4.550230646086673
# The value of the Gaussian NLL after Epoch # 592 is 4.550124356127356
# The value of the Gaussian NLL after Epoch # 593 is 4.5500176510126895
# The value of the Gaussian NLL after Epoch # 594 is 4.549911054317096
# The value of the Gaussian NLL after Epoch # 595 is 4.549804443940552
# The value of the Gaussian NLL after Epoch # 596 is 4.549697880536735
# The value of the Gaussian NLL after Epoch # 597 is 4.549591181038243
# The value of the Gaussian NLL after Epoch # 598 is 4.549484529613827
# The value of the Gaussian NLL after Epoch # 599 is 4.549377940113468
# The value of the Gaussian NLL after Epoch # 600 is 4.549271275933003
# The value of the Gaussian NLL after Epoch # 601 is 4.549164628529348
# The value of the Gaussian NLL after Epoch # 602 is 4.549058028356207
# The value of the Gaussian NLL after Epoch # 603 is 4.548951414472955
# The value of the Gaussian NLL after Epoch # 604 is 4.548844771394455
# The value of the Gaussian NLL after Epoch # 605 is 4.548738069228417
# The value of the Gaussian NLL after Epoch # 606 is 4.548631429208012
# The value of the Gaussian NLL after Epoch # 607 is 4.54852474506057
# The value of the Gaussian NLL after Epoch # 608 is 4.548418184462537
# The value of the Gaussian NLL after Epoch # 609 is 4.548311503378387
# The value of the Gaussian NLL after Epoch # 610 is 4.5482048991833475
# The value of the Gaussian NLL after Epoch # 611 is 4.548098175185235
# The value of the Gaussian NLL after Epoch # 612 is 4.547991453087528
# The value of the Gaussian NLL after Epoch # 613 is 4.547884822607297
# The value of the Gaussian NLL after Epoch # 614 is 4.547778194736046
# The value of the Gaussian NLL after Epoch # 615 is 4.54767155320095
# The value of the Gaussian NLL after Epoch # 616 is 4.547564851234645
# The value of the Gaussian NLL after Epoch # 617 is 4.547458136413508
# The value of the Gaussian NLL after Epoch # 618 is 4.547351558892623
# The value of the Gaussian NLL after Epoch # 619 is 4.547244770787719
# The value of the Gaussian NLL after Epoch # 620 is 4.547138045382382
# The value of the Gaussian NLL after Epoch # 621 is 4.547031396452623
# The value of the Gaussian NLL after Epoch # 622 is 4.5469247641662776
# The value of the Gaussian NLL after Epoch # 623 is 4.5468181035106605
# The value of the Gaussian NLL after Epoch # 624 is 4.546711338243003
# The value of the Gaussian NLL after Epoch # 625 is 4.546604665978293
# The value of the Gaussian NLL after Epoch # 626 is 4.54649802400069
# The value of the Gaussian NLL after Epoch # 627 is 4.546391247129744
# The value of the Gaussian NLL after Epoch # 628 is 4.546284562117472
# The value of the Gaussian NLL after Epoch # 629 is 4.546177956495652
# The value of the Gaussian NLL after Epoch # 630 is 4.546071200420153
# The value of the Gaussian NLL after Epoch # 631 is 4.54596447445172
# The value of the Gaussian NLL after Epoch # 632 is 4.545857765097878
# The value of the Gaussian NLL after Epoch # 633 is 4.545751043284729
# The value of the Gaussian NLL after Epoch # 634 is 4.545644293353206
# The value of the Gaussian NLL after Epoch # 635 is 4.545537633869738
# The value of the Gaussian NLL after Epoch # 636 is 4.5454309002388475
# The value of the Gaussian NLL after Epoch # 637 is 4.545324183217887
# The value of the Gaussian NLL after Epoch # 638 is 4.545217484107111
# The value of the Gaussian NLL after Epoch # 639 is 4.545110724079115
# The value of the Gaussian NLL after Epoch # 640 is 4.54500402800053
# The value of the Gaussian NLL after Epoch # 641 is 4.544897316968633
# The value of the Gaussian NLL after Epoch # 642 is 4.544790622529227
# The value of the Gaussian NLL after Epoch # 643 is 4.544683763490036
# The value of the Gaussian NLL after Epoch # 644 is 4.54457716263007
# The value of the Gaussian NLL after Epoch # 645 is 4.544470382845405
# The value of the Gaussian NLL after Epoch # 646 is 4.5443636182108476
# The value of the Gaussian NLL after Epoch # 647 is 4.544256824148724
# The value of the Gaussian NLL after Epoch # 648 is 4.544150062509011
# The value of the Gaussian NLL after Epoch # 649 is 4.544043331751624
# The value of the Gaussian NLL after Epoch # 650 is 4.543936574675914
# The value of the Gaussian NLL after Epoch # 651 is 4.54382989291272
# The value of the Gaussian NLL after Epoch # 652 is 4.543723091253491
# The value of the Gaussian NLL after Epoch # 653 is 4.543616336296252
# The value of the Gaussian NLL after Epoch # 654 is 4.543509597886704
# The value of the Gaussian NLL after Epoch # 655 is 4.543402847585773
# The value of the Gaussian NLL after Epoch # 656 is 4.543296051933985
# The value of the Gaussian NLL after Epoch # 657 is 4.5431892569222025
# The value of the Gaussian NLL after Epoch # 658 is 4.5430825244759525
# The value of the Gaussian NLL after Epoch # 659 is 4.542975750150614
# The value of the Gaussian NLL after Epoch # 660 is 4.542868974672265
# The value of the Gaussian NLL after Epoch # 661 is 4.542762185636016
# The value of the Gaussian NLL after Epoch # 662 is 4.542655399012964
# The value of the Gaussian NLL after Epoch # 663 is 4.542548673106943
# The value of the Gaussian NLL after Epoch # 664 is 4.542441845340479
# The value of the Gaussian NLL after Epoch # 665 is 4.542335182525809
# The value of the Gaussian NLL after Epoch # 666 is 4.542228249743314
# The value of the Gaussian NLL after Epoch # 667 is 4.542121529777804
# The value of the Gaussian NLL after Epoch # 668 is 4.54201466011175
# The value of the Gaussian NLL after Epoch # 669 is 4.541907883051383
# The value of the Gaussian NLL after Epoch # 670 is 4.541801212573494
# The value of the Gaussian NLL after Epoch # 671 is 4.541694392442196
# The value of the Gaussian NLL after Epoch # 672 is 4.541587590883443
# The value of the Gaussian NLL after Epoch # 673 is 4.54148077377026
# The value of the Gaussian NLL after Epoch # 674 is 4.541374003155466
# The value of the Gaussian NLL after Epoch # 675 is 4.541267142981688
# The value of the Gaussian NLL after Epoch # 676 is 4.541160345357592
# The value of the Gaussian NLL after Epoch # 677 is 4.541053564221423
# The value of the Gaussian NLL after Epoch # 678 is 4.540946723533068
# The value of the Gaussian NLL after Epoch # 679 is 4.540839945386463
# The value of the Gaussian NLL after Epoch # 680 is 4.540733137653152
# The value of the Gaussian NLL after Epoch # 681 is 4.5406263463840535
# The value of the Gaussian NLL after Epoch # 682 is 4.5405194817303505
# The value of the Gaussian NLL after Epoch # 683 is 4.540412633562513
# The value of the Gaussian NLL after Epoch # 684 is 4.540305891674248
# The value of the Gaussian NLL after Epoch # 685 is 4.540199030364231
# The value of the Gaussian NLL after Epoch # 686 is 4.540092231583187
# The value of the Gaussian NLL after Epoch # 687 is 4.539985283522645
# The value of the Gaussian NLL after Epoch # 688 is 4.539878577479192
# The value of the Gaussian NLL after Epoch # 689 is 4.539771692260142
# The value of the Gaussian NLL after Epoch # 690 is 4.539664853399646
# The value of the Gaussian NLL after Epoch # 691 is 4.539558001091657
# The value of the Gaussian NLL after Epoch # 692 is 4.539451224995727
# The value of the Gaussian NLL after Epoch # 693 is 4.539344269848245
# The value of the Gaussian NLL after Epoch # 694 is 4.539237483071785
# The value of the Gaussian NLL after Epoch # 695 is 4.539130544615685
# The value of the Gaussian NLL after Epoch # 696 is 4.539023774478661
# ...
# The value of the Gaussian NLL after Epoch # 11438 is 4.140834149535709
# The value of the Gaussian NLL after Epoch # 11439 is 4.140833983189416
# The value of the Gaussian NLL after Epoch # 11440 is 4.140833802161424
# The value of the Gaussian NLL after Epoch # 11441 is 4.1408336922168445
# The value of the Gaussian NLL after Epoch # 11442 is 4.14083352608854
# The value of the Gaussian NLL after Epoch # 11443 is 4.140833308573753
# The value of the Gaussian NLL after Epoch # 11444 is 4.14083319884702
# The value of the Gaussian NLL after Epoch # 11445 is 4.140832964324456
# The value of the Gaussian NLL after Epoch # 11446 is 4.140832798486828
# The value of the Gaussian NLL after Epoch # 11447 is 4.14083268897794
# The value of the Gaussian NLL after Epoch # 11448 is 4.140832523285668
# The value of the Gaussian NLL after Epoch # 11449 is 4.140832342911296
# The value of the Gaussian NLL after Epoch # 11450 is 4.140832125905059
# The value of the Gaussian NLL after Epoch # 11451 is 4.140832016686624
# The value of the Gaussian NLL after Epoch # 11452 is 4.140831851285012
# The value of the Gaussian NLL after Epoch # 11453 is 4.140831671201146
# The value of the Gaussian NLL after Epoch # 11454 is 4.140831508343022
# The value of the Gaussian NLL after Epoch # 11455 is 4.140831343159418
# The value of the Gaussian NLL after Epoch # 11456 is 4.140831163293433
# The value of the Gaussian NLL after Epoch # 11457 is 4.140830946795748
# The value of the Gaussian NLL after Epoch # 11458 is 4.140830838085617
# The value of the Gaussian NLL after Epoch # 11459 is 4.140830658437506
# The value of the Gaussian NLL after Epoch # 11460 is 4.140830493617197
# The value of the Gaussian NLL after Epoch # 11461 is 4.140830331267503
# The value of the Gaussian NLL after Epoch # 11462 is 4.140830166592569
# The value of the Gaussian NLL after Epoch # 11463 is 4.1408299872349765
# The value of the Gaussian NLL after Epoch # 11464 is 4.140829825103186
# The value of the Gaussian NLL after Epoch # 11465 is 4.1408296630440224
# The value of the Gaussian NLL after Epoch # 11466 is 4.140829498659751
# The value of the Gaussian NLL after Epoch # 11467 is 4.140829319592669
# The value of the Gaussian NLL after Epoch # 11468 is 4.140829157751408
# The value of the Gaussian NLL after Epoch # 11469 is 4.140828993585146
# The value of the Gaussian NLL after Epoch # 11470 is 4.14082881473595
# The value of the Gaussian NLL after Epoch # 11471 is 4.140828653112595
# The value of the Gaussian NLL after Epoch # 11472 is 4.140828491561868
# The value of the Gaussian NLL after Epoch # 11473 is 4.140828327686268
# The value of the Gaussian NLL after Epoch # 11474 is 4.140828149127585
# The value of the Gaussian NLL after Epoch # 11475 is 4.140827985397345
# The value of the Gaussian NLL after Epoch # 11476 is 4.140827824137175
# The value of the Gaussian NLL after Epoch # 11477 is 4.140827645796381
# The value of the Gaussian NLL after Epoch # 11478 is 4.140827482284152
# The value of the Gaussian NLL after Epoch # 11479 is 4.140827375098963
# The value of the Gaussian NLL after Epoch # 11480 is 4.140827231282587
# The value of the Gaussian NLL after Epoch # 11481 is 4.140827124242604
# The value of the Gaussian NLL after Epoch # 11482 is 4.140826970620297
# The value of the Gaussian NLL after Epoch # 11483 is 4.140826802306202
# The value of the Gaussian NLL after Epoch # 11484 is 4.140826648812651
# The value of the Gaussian NLL after Epoch # 11485 is 4.140826355759976
# The value of the Gaussian NLL after Epoch # 11486 is 4.140826258649182
# The value of the Gaussian NLL after Epoch # 11487 is 4.14082610534874
# The value of the Gaussian NLL after Epoch # 11488 is 4.140826025519906
# The value of the Gaussian NLL after Epoch # 11489 is 4.1408258723482385
# The value of the Gaussian NLL after Epoch # 11490 is 4.140825721637829
# The value of the Gaussian NLL after Epoch # 11491 is 4.140825553838409
# The value of the Gaussian NLL after Epoch # 11492 is 4.1408254008598515
# The value of the Gaussian NLL after Epoch # 11493 is 4.14082525034246
# The value of the Gaussian NLL after Epoch # 11494 is 4.140825082736046
# The value of the Gaussian NLL after Epoch # 11495 is 4.1408249299506
# The value of the Gaussian NLL after Epoch # 11496 is 4.140824779626228
# The value of the Gaussian NLL after Epoch # 11497 is 4.140824629366191
# The value of the Gaussian NLL after Epoch # 11498 is 4.140824476773871
# The value of the Gaussian NLL after Epoch # 11499 is 4.140824309489132
# The value of the Gaussian NLL after Epoch # 11500 is 4.1408241570255715
# The value of the Gaussian NLL after Epoch # 11501 is 4.140824060879618
# The value of the Gaussian NLL after Epoch # 11502 is 4.140823908544815
# The value of the Gaussian NLL after Epoch # 11503 is 4.140823687660726
# The value of the Gaussian NLL after Epoch # 11504 is 4.140823537851084
# The value of the Gaussian NLL after Epoch # 11505 is 4.140823388105775
# The value of the Gaussian NLL after Epoch # 11506 is 4.140823221271383
# The value of the Gaussian NLL after Epoch # 11507 is 4.140823069258402
# The value of the Gaussian NLL after Epoch # 11508 is 4.14082297356271
# The value of the Gaussian NLL after Epoch # 11509 is 4.140822821678486
# The value of the Gaussian NLL after Epoch # 11510 is 4.140822601244862
# The value of the Gaussian NLL after Epoch # 11511 is 4.140822451885597
# The value of the Gaussian NLL after Epoch # 11512 is 4.140822300194501
# The value of the Gaussian NLL after Epoch # 11513 is 4.140822150963928
# The value of the Gaussian NLL after Epoch # 11514 is 4.140821984644226
# The value of the Gaussian NLL after Epoch # 11515 is 4.140821833146244
# The value of the Gaussian NLL after Epoch # 11516 is 4.140821737965157
# The value of the Gaussian NLL after Epoch # 11517 is 4.140821517982
# The value of the Gaussian NLL after Epoch # 11518 is 4.140821366677133
# The value of the Gaussian NLL after Epoch # 11519 is 4.140821217832605
# The value of the Gaussian NLL after Epoch # 11520 is 4.140821122908814
# The value of the Gaussian NLL after Epoch # 11521 is 4.140820971797059
# The value of the Gaussian NLL after Epoch # 11522 is 4.140820752135668
# The value of the Gaussian NLL after Epoch # 11523 is 4.14082060115269
# The value of the Gaussian NLL after Epoch # 11524 is 4.140820506486213
# The value of the Gaussian NLL after Epoch # 11525 is 4.1408203408742015
# The value of the Gaussian NLL after Epoch # 11526 is 4.1408201900843205
# The value of the Gaussian NLL after Epoch # 11527 is 4.140820129917887
# The value of the Gaussian NLL after Epoch # 11528 is 4.140819979256798
# The value of the Gaussian NLL after Epoch # 11529 is 4.140819742892305
# The value of the Gaussian NLL after Epoch # 11530 is 4.140819594755531
# The value of the Gaussian NLL after Epoch # 11531 is 4.140819429529539
# The value of the Gaussian NLL after Epoch # 11532 is 4.140819279125906
# The value of the Gaussian NLL after Epoch # 11533 is 4.140819185038348
# The value of the Gaussian NLL after Epoch # 11534 is 4.140819034763474
# The value of the Gaussian NLL after Epoch # 11535 is 4.14081890410199
# The value of the Gaussian NLL after Epoch # 11536 is 4.140818668187946
# The value of the Gaussian NLL after Epoch # 11537 is 4.140818518106205
# The value of the Gaussian NLL after Epoch # 11538 is 4.140818441493885
# The value of the Gaussian NLL after Epoch # 11539 is 4.1408182915409215
# The value of the Gaussian NLL after Epoch # 11540 is 4.140818055884266
# The value of the Gaussian NLL after Epoch # 11541 is 4.1408180333210005
# The value of the Gaussian NLL after Epoch # 11542 is 4.1408178835611364
# The value of the Gaussian NLL after Epoch # 11543 is 4.140817682404772
# The value of the Gaussian NLL after Epoch # 11544 is 4.140817447005521
# The value of the Gaussian NLL after Epoch # 11545 is 4.140817424699505
# The value of the Gaussian NLL after Epoch # 11546 is 4.140817275197115
# The value of the Gaussian NLL after Epoch # 11547 is 4.1408171257591455
# The value of the Gaussian NLL after Epoch # 11548 is 4.1408168367613225
# The value of the Gaussian NLL after Epoch # 11549 is 4.140816814712594
# The value of the Gaussian NLL after Epoch # 11550 is 4.140816665467742
# The value of the Gaussian NLL after Epoch # 11551 is 4.140816464826262
# The value of the Gaussian NLL after Epoch # 11552 is 4.140816300951358
# The value of the Gaussian NLL after Epoch # 11553 is 4.1408161518996405
# The value of the Gaussian NLL after Epoch # 11554 is 4.1408160591629555
# The value of the Gaussian NLL after Epoch # 11555 is 4.140815910239999
# The value of the Gaussian NLL after Epoch # 11556 is 4.140815692766621
# The value of the Gaussian NLL after Epoch # 11557 is 4.140815600222919
# The value of the Gaussian NLL after Epoch # 11558 is 4.140815451493082
# The value of the Gaussian NLL after Epoch # 11559 is 4.140815305222257
# The value of the Gaussian NLL after Epoch # 11560 is 4.1408150880063
# The value of the Gaussian NLL after Epoch # 11561 is 4.140814939469597
# The value of the Gaussian NLL after Epoch # 11562 is 4.140814847247544
# The value of the Gaussian NLL after Epoch # 11563 is 4.140814698839603
# The value of the Gaussian NLL after Epoch # 11564 is 4.140814481881072
# The value of the Gaussian NLL after Epoch # 11565 is 4.140814389852004
# The value of the Gaussian NLL after Epoch # 11566 is 4.140814241637182
# The value of the Gaussian NLL after Epoch # 11567 is 4.140814095881121
# The value of the Gaussian NLL after Epoch # 11568 is 4.140813947795078
# The value of the Gaussian NLL after Epoch # 11569 is 4.140813802167712
# The value of the Gaussian NLL after Epoch # 11570 is 4.14081363945091
# The value of the Gaussian NLL after Epoch # 11571 is 4.140813491557987
# The value of the Gaussian NLL after Epoch # 11572 is 4.140813399979219
# The value of the Gaussian NLL after Epoch # 11573 is 4.140813252215059
# The value of the Gaussian NLL after Epoch # 11574 is 4.1408130359000745
# The value of the Gaussian NLL after Epoch # 11575 is 4.140812890658779
# The value of the Gaussian NLL after Epoch # 11576 is 4.140812745481824
# The value of the Gaussian NLL after Epoch # 11577 is 4.140812597975158
# The value of the Gaussian NLL after Epoch # 11578 is 4.140812435773082
# The value of the Gaussian NLL after Epoch # 11579 is 4.140812344644615
# The value of the Gaussian NLL after Epoch # 11580 is 4.140812197331055
# The value of the Gaussian NLL after Epoch # 11581 is 4.140811981466568
# The value of the Gaussian NLL after Epoch # 11582 is 4.140811836675685
# The value of the Gaussian NLL after Epoch # 11583 is 4.140811689555262
# The value of the Gaussian NLL after Epoch # 11584 is 4.140811542499261
# The value of the Gaussian NLL after Epoch # 11585 is 4.140811451756791
# The value of the Gaussian NLL after Epoch # 11586 is 4.140811236214091
# The value of the Gaussian NLL after Epoch # 11587 is 4.140811089351212
# The value of the Gaussian NLL after Epoch # 11588 is 4.140810998801733
# The value of the Gaussian NLL after Epoch # 11589 is 4.140810837307399
# The value of the Gaussian NLL after Epoch # 11590 is 4.140810690637626
# The value of the Gaussian NLL after Epoch # 11591 is 4.140810544032275
# The value of the Gaussian NLL after Epoch # 11592 is 4.140810346029623
# The value of the Gaussian NLL after Epoch # 11593 is 4.140810255801802
# The value of the Gaussian NLL after Epoch # 11594 is 4.140810040773965
# The value of the Gaussian NLL after Epoch # 11595 is 4.140809950674794
# The value of the Gaussian NLL after Epoch # 11596 is 4.140809804391283
# The value of the Gaussian NLL after Epoch # 11597 is 4.140809658172194
# The value of the Gaussian NLL after Epoch # 11598 is 4.140809497256941
# The value of the Gaussian NLL after Epoch # 11599 is 4.140809299704821
# The value of the Gaussian NLL after Epoch # 11600 is 4.140809280936359
# The value of the Gaussian NLL after Epoch # 11601 is 4.140809134974752
# The value of the Gaussian NLL after Epoch # 11602 is 4.140808849452733
# The value of the Gaussian NLL after Epoch # 11603 is 4.140808759868219
# The value of the Gaussian NLL after Epoch # 11604 is 4.140808614099736
# The value of the Gaussian NLL after Epoch # 11605 is 4.140808468395676
# The value of the Gaussian NLL after Epoch # 11606 is 4.140808307995165
# The value of the Gaussian NLL after Epoch # 11607 is 4.140808252975913
# The value of the Gaussian NLL after Epoch # 11608 is 4.140808107464992
# The value of the Gaussian NLL after Epoch # 11609 is 4.140807947257488
# The value of the Gaussian NLL after Epoch # 11610 is 4.140807801875333
# The value of the Gaussian NLL after Epoch # 11611 is 4.140807570787578
# The value of the Gaussian NLL after Epoch # 11612 is 4.140807498936045
# The value of the Gaussian NLL after Epoch # 11613 is 4.140807353747016
# The value of the Gaussian NLL after Epoch # 11614 is 4.140807122852328
# The value of the Gaussian NLL after Epoch # 11615 is 4.140806977792064
# The value of the Gaussian NLL after Epoch # 11616 is 4.140806923351927
# The value of the Gaussian NLL after Epoch # 11617 is 4.140806763659173
# The value of the Gaussian NLL after Epoch # 11618 is 4.14080661879205
# The value of the Gaussian NLL after Epoch # 11619 is 4.140806530236848
# The value of the Gaussian NLL after Epoch # 11620 is 4.140806385498491
# The value of the Gaussian NLL after Epoch # 11621 is 4.1408061722083085
# The value of the Gaussian NLL after Epoch # 11622 is 4.140806083846104
# The value of the Gaussian NLL after Epoch # 11623 is 4.140805939300873
# The value of the Gaussian NLL after Epoch # 11624 is 4.140805780058514
# The value of the Gaussian NLL after Epoch # 11625 is 4.140805635642051
# The value of the Gaussian NLL after Epoch # 11626 is 4.14080549129001
# The value of the Gaussian NLL after Epoch # 11627 is 4.140805304556174
# The value of the Gaussian NLL after Epoch # 11628 is 4.140805225588286
# The value of the Gaussian NLL after Epoch # 11629 is 4.140805021813489
# The value of the Gaussian NLL after Epoch # 11630 is 4.140804942958673
# The value of the Gaussian NLL after Epoch # 11631 is 4.14080480791338
# The value of the Gaussian NLL after Epoch # 11632 is 4.140804672924708
# The value of the Gaussian NLL after Epoch # 11633 is 4.140804523230784
# The value of the Gaussian NLL after Epoch # 11634 is 4.140804336892929
# The value of the Gaussian NLL after Epoch # 11635 is 4.140804258320817
# The value of the Gaussian NLL after Epoch # 11636 is 4.140804123558442
# The value of the Gaussian NLL after Epoch # 11637 is 4.140803974090726
# The value of the Gaussian NLL after Epoch # 11638 is 4.14080383944152
# The value of the Gaussian NLL after Epoch # 11639 is 4.140803704848937
# The value of the Gaussian NLL after Epoch # 11640 is 4.140803572705019
# The value of the Gaussian NLL after Epoch # 11641 is 4.1408034234635105
# The value of the Gaussian NLL after Epoch # 11642 is 4.140803289040659
# The value of the Gaussian NLL after Epoch # 11643 is 4.140803103211942
# The value of the Gaussian NLL after Epoch # 11644 is 4.140803025148709
# The value of the Gaussian NLL after Epoch # 11645 is 4.140802890895607
# The value of the Gaussian NLL after Epoch # 11646 is 4.140802741936857
# The value of the Gaussian NLL after Epoch # 11647 is 4.140802607796925
# The value of the Gaussian NLL after Epoch # 11648 is 4.140802476105455
# The value of the Gaussian NLL after Epoch # 11649 is 4.140802342078708
# The value of the Gaussian NLL after Epoch # 11650 is 4.1408021933461665
# The value of the Gaussian NLL after Epoch # 11651 is 4.140802059432591
# The value of the Gaussian NLL after Epoch # 11652 is 4.1408019279673525
# The value of the Gaussian NLL after Epoch # 11653 is 4.140801794166963
# The value of the Gaussian NLL after Epoch # 11654 is 4.140801662814839
# The value of the Gaussian NLL after Epoch # 11655 is 4.140801514365059
# The value of the Gaussian NLL after Epoch # 11656 is 4.140801380734404
# The value of the Gaussian NLL after Epoch # 11657 is 4.140801303406214
# The value of the Gaussian NLL after Epoch # 11658 is 4.1408011698887295
# The value of the Gaussian NLL after Epoch # 11659 is 4.140800967810909
# The value of the Gaussian NLL after Epoch # 11660 is 4.140800834406611
# The value of the Gaussian NLL after Epoch # 11661 is 4.140800845467298
# The value of the Gaussian NLL after Epoch # 11662 is 4.140800712176187

# %%
list(MLEstimatorNN.parameters())
# Out:
# [Parameter containing:
#  tensor([-108.8365], requires_grad=True),
#  Parameter containing:
#  tensor([2.7219], requires_grad=True)]
