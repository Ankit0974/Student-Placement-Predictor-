# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import math

# %%
data = pd.read_csv("college_student_placement_dataset.csv")

# %%
data.head()
# Out:
#   College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0    CLG0030  107             6.61  6.28                     8
# 1    CLG0061   97             5.52  5.37                     8
# 2    CLG0036  109             5.36  5.83                     9
# 3    CLG0055  122             5.47  5.75                     6
# 4    CLG0004   96             7.91  7.69                     7
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                       8                     8
# 1                    No                       7                     8
# 2                    No                       3                     1
# 3                   Yes                       1                     6
# 4                    No                       8                    10
#
#    Projects_Completed Placement
# 0                   4        No
# 1                   0        No
# 2                   1        No
# 3                   1        No
# 4                   2        No

# %%
no_yes_dict = {"No":0,"Yes":1}
data[data.columns[5]] = data[data.columns[5]].map(no_yes_dict)
data[data.columns[-1]] =data[data.columns[-1]].map(no_yes_dict)

# %%
data[data.columns[0]] = data[data.columns[0]].apply(lambda x: int(x[3:]))

# %%
data.head()
# Out:
#    College_ID   IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0          30  107             6.61  6.28                     8
# 1          61   97             5.52  5.37                     8
# 2          36  109             5.36  5.83                     9
# 3          55  122             5.47  5.75                     6
# 4           4   96             7.91  7.69                     7
#
#    Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                      0                       8                     8
# 1                      0                       7                     8
# 2                      0                       3                     1
# 3                      1                       1                     6
# 4                      0                       8                    10
#
#    Projects_Completed  Placement
# 0                   4          0
# 1                   0          0
# 2                   1          0
# 3                   1          0
# 4                   2          0

# %%
corr_matrix = data.corr()

# %%
corr_matrix
# Out:
#                         College_ID        IQ  Prev_Sem_Result      CGPA  \
# College_ID                1.000000  0.002473        -0.004060 -0.003422
# IQ                        0.002473  1.000000        -0.002640 -0.002859
# Prev_Sem_Result          -0.004060 -0.002640         1.000000  0.980768
# CGPA                     -0.003422 -0.002859         0.980768  1.000000
# Academic_Performance     -0.015442 -0.006827        -0.005765 -0.002958
# Internship_Experience     0.012037 -0.000247        -0.013347 -0.012562
# Extra_Curricular_Score   -0.003931 -0.003458         0.009326  0.011441
# Communication_Skills     -0.005194 -0.010896        -0.017269 -0.018242
# Projects_Completed        0.004903  0.014538         0.018434  0.020872
# Placement                 0.002750  0.285914         0.317896  0.321607
#
#                         Academic_Performance  Internship_Experience  \
# College_ID                         -0.015442               0.012037
# IQ                                 -0.006827              -0.000247
# Prev_Sem_Result                    -0.005765              -0.013347
# CGPA                               -0.002958              -0.012562
# Academic_Performance                1.000000               0.025903
# Internship_Experience               0.025903               1.000000
# Extra_Curricular_Score              0.011774               0.002093
# Communication_Skills               -0.019733              -0.020437
# Projects_Completed                 -0.013148              -0.010260
# Placement                          -0.014920              -0.005841
#
#                         Extra_Curricular_Score  Communication_Skills  \
# College_ID                           -0.003931             -0.005194
# IQ                                   -0.003458             -0.010896
# Prev_Sem_Result                       0.009326             -0.017269
# CGPA                                  0.011441             -0.018242
# Academic_Performance                  0.011774             -0.019733
# Internship_Experience                 0.002093             -0.020437
# Extra_Curricular_Score                1.000000              0.003769
# Communication_Skills                  0.003769              1.000000
# Projects_Completed                    0.008122             -0.004486
# Placement                            -0.004740              0.323155
#
#                         Projects_Completed  Placement
# College_ID                        0.004903   0.002750
# IQ                                0.014538   0.285914
# Prev_Sem_Result                   0.018434   0.317896
# CGPA                              0.020872   0.321607
# Academic_Performance             -0.013148  -0.014920
# Internship_Experience            -0.010260  -0.005841
# Extra_Curricular_Score            0.008122  -0.004740
# Communication_Skills             -0.004486   0.323155
# Projects_Completed                1.000000   0.217499
# Placement                         0.217499   1.000000

# %%
feature_selected_data = data[[data.columns[1],data.columns[2],
                             data.columns[3],data.columns[7],
                             data.columns[8],data.columns[9]]]

# %%
feature_selected_data.head()
# Out:
#     IQ  Prev_Sem_Result  CGPA  Communication_Skills  Projects_Completed  \
# 0  107             6.61  6.28                     8                   4
# 1   97             5.52  5.37                     8                   0
# 2  109             5.36  5.83                     1                   1
# 3  122             5.47  5.75                     6                   1
# 4   96             7.91  7.69                    10                   2
#
#    Placement
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
placement_equals_1_prior = data[data[data.columns[-1]] == 1].shape[0]/data.shape[0]

# %%
placement_equals_1_prior
# Out:
# 0.1659

# %%
sns.heatmap(feature_selected_data.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(feature_selected_data.iloc[:,0:-1].corr(),annot=True)
# Out:
# <Axes: >

# %%
X = np.array(feature_selected_data.iloc[:,0:-1])
cov_mat = np.cov(X,rowvar=False)
F = np.linalg.svd(cov_mat)

# %%
E = F[0]
lamda = F[1]
new_X = np.matmul(X,F[0])
new_cov_mat = np.cov(new_X,rowvar=False)

# %%
new_input_features = pd.DataFrame(data=new_X,
                            columns=["Input_feat_1", "Input_feat_2","Input_feat_3",
                                     "Input_feat_4","Input_feat_5"])

# %%
new_input_features
# Out:
#       Input_feat_1  Input_feat_2  Input_feat_3  Input_feat_4  Input_feat_5
# 0      -106.985375     -7.981836     -9.555150      3.340004     -0.306328
# 1       -96.979236     -8.012939     -7.923885     -0.560073     -0.162169
# 2      -108.996045     -1.031525     -8.018326      0.386976      0.270885
# 3      -121.985085     -6.057694     -8.170966      0.378047      0.138325
# 4       -95.976963     -9.916990    -11.407312      1.263163     -0.240179
# ...            ...           ...           ...           ...           ...
# 9995   -118.977579     -7.956445    -12.032431     -0.820737     -0.172895
# 9996    -69.982793     -6.807540    -13.433592      1.183742     -0.039127
# 9997    -88.985088     -8.947921     -9.236363      4.393741      0.048864
# 9998   -106.985575     -4.909174    -12.706018      0.151579      0.009777
# 9999   -108.991878     -4.869663    -13.976734      4.085093      0.144073
#
# [10000 rows x 5 columns]

# %%
sns.heatmap(new_input_features.corr(),annot=True)
# Out:
# <Axes: >

# %%
new_data = pd.concat([new_input_features,feature_selected_data[data.columns[-1]]],
                     axis=1)

# %%
new_data
# Out:
#       Input_feat_1  Input_feat_2  Input_feat_3  Input_feat_4  Input_feat_5  \
# 0      -106.985375     -7.981836     -9.555150      3.340004     -0.306328
# 1       -96.979236     -8.012939     -7.923885     -0.560073     -0.162169
# 2      -108.996045     -1.031525     -8.018326      0.386976      0.270885
# 3      -121.985085     -6.057694     -8.170966      0.378047      0.138325
# 4       -95.976963     -9.916990    -11.407312      1.263163     -0.240179
# ...            ...           ...           ...           ...           ...
# 9995   -118.977579     -7.956445    -12.032431     -0.820737     -0.172895
# 9996    -69.982793     -6.807540    -13.433592      1.183742     -0.039127
# 9997    -88.985088     -8.947921     -9.236363      4.393741      0.048864
# 9998   -106.985575     -4.909174    -12.706018      0.151579      0.009777
# 9999   -108.991878     -4.869663    -13.976734      4.085093      0.144073
#
#       Placement
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ...         ...
# 9995          1
# 9996          0
# 9997          0
# 9998          0
# 9999          0
#
# [10000 rows x 6 columns]

# %%
plt.hist(new_data[new_data[new_data.columns[-1]] == 1][new_data.columns[0]])
# Out:
# (array([  3.,  22., 101., 362., 572., 236., 208., 109.,  38.,   8.]),
#  array([-157.98374855, -147.7834374 , -137.58312626, -127.38281511,
#         -117.18250397, -106.98219282,  -96.78188168,  -86.58157053,
#          -76.38125939,  -66.18094824,  -55.98063709]),
#  <BarContainer object of 10 artists>)

# %%
new_data[new_data[new_data.columns[-1]] == 1][new_data.columns[0]]
# Out:
# 6      -122.981852
# 7      -110.996007
# 18      -85.982336
# 20     -120.993575
# 23      -77.976418
#            ...
# 9964   -122.993803
# 9978    -83.981477
# 9992   -108.977394
# 9994   -116.992906
# 9995   -118.977579
# Name: Input_feat_1, Length: 1659, dtype: float64

# %%
class GaussianMLEstimatorNN(torch.nn.Module):

    def __init__(self):
        super().__init__()

        self.mu = torch.nn.Parameter(data=torch.tensor([-90.0]))
        self.log_sigma = torch.nn.Parameter(data=torch.tensor([1.0]))

    def forward(self,x):

        g = -self.mu
        h = (x + g)
        i = h**2
        sigma = torch.exp(self.log_sigma)
        j = (-1/(2*sigma**2))*i
        k = torch.exp(j)
        l = (1/(math.sqrt(2*math.pi)*sigma))*k
        f = torch.log(l)

        return -torch.mean(f)

# %%
MLEstimatorNN = GaussianMLEstimatorNN()
optimizer = torch.optim.SGD(params=MLEstimatorNN.parameters(),lr=0.01)
x = torch.tensor(new_data[new_data[new_data.columns[-1]] == 1][new_data.columns[0]].values)
tol = 10**(-8)

# %%
epoch = 0
while True:

    initial_loss_function_value = MLEstimatorNN(x)
    optimizer.zero_grad()
    initial_loss_function_value.backward()
    optimizer.step()
    final_loss_function_value = MLEstimatorNN(x)

    if torch.abs(initial_loss_function_value - final_loss_function_value) < tol:
        break

    epoch += 1

    print("The value of the Gaussian NLL after Epoch # {} is {}".format(epoch,initial_loss_function_value.item()))
# Out:
# The value of the Gaussian NLL after Epoch # 1 is 42.266029066311944
# The value of the Gaussian NLL after Epoch # 2 is 10.898221688176298
# The value of the Gaussian NLL after Epoch # 3 is 8.885079965936018
# The value of the Gaussian NLL after Epoch # 4 is 7.8032378321639335
# The value of the Gaussian NLL after Epoch # 5 is 7.122905193161005
# The value of the Gaussian NLL after Epoch # 6 is 6.655513930892801
# The value of the Gaussian NLL after Epoch # 7 is 6.3153461033581095
# The value of the Gaussian NLL after Epoch # 8 is 6.057430698282627
# The value of the Gaussian NLL after Epoch # 9 is 5.855789352261758
# The value of the Gaussian NLL after Epoch # 10 is 5.694332264578116
# The value of the Gaussian NLL after Epoch # 11 is 5.5625475592774265
# The value of the Gaussian NLL after Epoch # 12 is 5.4532769206309855
# The value of the Gaussian NLL after Epoch # 13 is 5.361472378881932
# The value of the Gaussian NLL after Epoch # 14 is 5.283475533108172
# The value of the Gaussian NLL after Epoch # 15 is 5.21656987180526
# The value of the Gaussian NLL after Epoch # 16 is 5.158696764484863
# The value of the Gaussian NLL after Epoch # 17 is 5.108268151835828
# The value of the Gaussian NLL after Epoch # 18 is 5.064040816924186
# The value of the Gaussian NLL after Epoch # 19 is 5.025027947878673
# The value of the Gaussian NLL after Epoch # 20 is 4.9904354652043335
# The value of the Gaussian NLL after Epoch # 21 is 4.9596188032714235
# The value of the Gaussian NLL after Epoch # 22 is 4.93204958013114
# The value of the Gaussian NLL after Epoch # 23 is 4.907290598412101
# The value of the Gaussian NLL after Epoch # 24 is 4.884976746764537
# The value of the Gaussian NLL after Epoch # 25 is 4.864802400153693
# The value of the Gaussian NLL after Epoch # 26 is 4.846506990401105
# The value of the Gaussian NLL after Epoch # 27 is 4.829870411929188
# The value of the Gaussian NLL after Epoch # 28 is 4.814703589285442
# The value of the Gaussian NLL after Epoch # 29 is 4.800843558517688
# The value of the Gaussian NLL after Epoch # 30 is 4.788150458488759
# The value of the Gaussian NLL after Epoch # 31 is 4.776501663871288
# The value of the Gaussian NLL after Epoch # 32 is 4.765791079566591
# The value of the Gaussian NLL after Epoch # 33 is 4.75592524373439
# The value of the Gaussian NLL after Epoch # 34 is 4.746822535257224
# The value of the Gaussian NLL after Epoch # 35 is 4.738409869362229
# The value of the Gaussian NLL after Epoch # 36 is 4.730623907765678
# The value of the Gaussian NLL after Epoch # 37 is 4.723406942358151
# The value of the Gaussian NLL after Epoch # 38 is 4.716708992119687
# The value of the Gaussian NLL after Epoch # 39 is 4.710485010362008
# The value of the Gaussian NLL after Epoch # 40 is 4.704694241125552
# The value of the Gaussian NLL after Epoch # 41 is 4.699300600897042
# The value of the Gaussian NLL after Epoch # 42 is 4.694271058667352
# The value of the Gaussian NLL after Epoch # 43 is 4.689576534340139
# The value of the Gaussian NLL after Epoch # 44 is 4.6851902456027945
# The value of the Gaussian NLL after Epoch # 45 is 4.681088302208924
# The value of the Gaussian NLL after Epoch # 46 is 4.677248765432169
# The value of the Gaussian NLL after Epoch # 47 is 4.6736516239561
# The value of the Gaussian NLL after Epoch # 48 is 4.670278779840019
# The value of the Gaussian NLL after Epoch # 49 is 4.667113924676109
# The value of the Gaussian NLL after Epoch # 50 is 4.664142154469131
# The value of the Gaussian NLL after Epoch # 51 is 4.6613498103403
# The value of the Gaussian NLL after Epoch # 52 is 4.658723695867029
# The value of the Gaussian NLL after Epoch # 53 is 4.656252620978631
# The value of the Gaussian NLL after Epoch # 54 is 4.65392615743974
# The value of the Gaussian NLL after Epoch # 55 is 4.651734053366881
# The value of the Gaussian NLL after Epoch # 56 is 4.64966765281303
# The value of the Gaussian NLL after Epoch # 57 is 4.647718356883218
# The value of the Gaussian NLL after Epoch # 58 is 4.645878918785052
# The value of the Gaussian NLL after Epoch # 59 is 4.644141833620016
# The value of the Gaussian NLL after Epoch # 60 is 4.642500903195998
# The value of the Gaussian NLL after Epoch # 61 is 4.640949817961283
# The value of the Gaussian NLL after Epoch # 62 is 4.6394831268607835
# The value of the Gaussian NLL after Epoch # 63 is 4.63809539063048
# The value of the Gaussian NLL after Epoch # 64 is 4.636782149216214
# The value of the Gaussian NLL after Epoch # 65 is 4.635538450971828
# The value of the Gaussian NLL after Epoch # 66 is 4.63436053016235
# The value of the Gaussian NLL after Epoch # 67 is 4.633244084071663
# The value of the Gaussian NLL after Epoch # 68 is 4.632185463804994
# The value of the Gaussian NLL after Epoch # 69 is 4.631181766875868
# The value of the Gaussian NLL after Epoch # 70 is 4.630229399662454
# The value of the Gaussian NLL after Epoch # 71 is 4.62932535128106
# The value of the Gaussian NLL after Epoch # 72 is 4.62846723538826
# The value of the Gaussian NLL after Epoch # 73 is 4.627652087015245
# The value of the Gaussian NLL after Epoch # 74 is 4.6268774968420905
# The value of the Gaussian NLL after Epoch # 75 is 4.626141606790824
# The value of the Gaussian NLL after Epoch # 76 is 4.625441895970419
# The value of the Gaussian NLL after Epoch # 77 is 4.6247763651848866
# The value of the Gaussian NLL after Epoch # 78 is 4.624143296664588
# The value of the Gaussian NLL after Epoch # 79 is 4.623541002388976
# The value of the Gaussian NLL after Epoch # 80 is 4.622967700504044
# The value of the Gaussian NLL after Epoch # 81 is 4.622421749524548
# The value of the Gaussian NLL after Epoch # 82 is 4.621901669589602
# The value of the Gaussian NLL after Epoch # 83 is 4.621406549044513
# The value of the Gaussian NLL after Epoch # 84 is 4.620934630687087
# The value of the Gaussian NLL after Epoch # 85 is 4.6204847907649285
# The value of the Gaussian NLL after Epoch # 86 is 4.620055826364949
# The value of the Gaussian NLL after Epoch # 87 is 4.619646951023088
# The value of the Gaussian NLL after Epoch # 88 is 4.619256949965338
# The value of the Gaussian NLL after Epoch # 89 is 4.618884888645652
# The value of the Gaussian NLL after Epoch # 90 is 4.618529604917541
# The value of the Gaussian NLL after Epoch # 91 is 4.618190505952954
# The value of the Gaussian NLL after Epoch # 92 is 4.617866926880505
# The value of the Gaussian NLL after Epoch # 93 is 4.617557772454436
# The value of the Gaussian NLL after Epoch # 94 is 4.6172624962047
# The value of the Gaussian NLL after Epoch # 95 is 4.616980391661941
# The value of the Gaussian NLL after Epoch # 96 is 4.616710550002001
# The value of the Gaussian NLL after Epoch # 97 is 4.616452746720899
# The value of the Gaussian NLL after Epoch # 98 is 4.616206086997503
# The value of the Gaussian NLL after Epoch # 99 is 4.6159704359780225
# The value of the Gaussian NLL after Epoch # 100 is 4.615745025255692
# The value of the Gaussian NLL after Epoch # 101 is 4.615529343181004
# The value of the Gaussian NLL after Epoch # 102 is 4.615322930701367
# The value of the Gaussian NLL after Epoch # 103 is 4.615125191152412
# The value of the Gaussian NLL after Epoch # 104 is 4.614935877376267
# The value of the Gaussian NLL after Epoch # 105 is 4.6147544736511055
# The value of the Gaussian NLL after Epoch # 106 is 4.61458112958919
# The value of the Gaussian NLL after Epoch # 107 is 4.614414825868939
# The value of the Gaussian NLL after Epoch # 108 is 4.614255512108046
# The value of the Gaussian NLL after Epoch # 109 is 4.614102738330161
# The value of the Gaussian NLL after Epoch # 110 is 4.613956358904037
# The value of the Gaussian NLL after Epoch # 111 is 4.61381579816148
# The value of the Gaussian NLL after Epoch # 112 is 4.613681050462291
# The value of the Gaussian NLL after Epoch # 113 is 4.613551684196208
# The value of the Gaussian NLL after Epoch # 114 is 4.61342750992131
# The value of the Gaussian NLL after Epoch # 115 is 4.6133085782472545
# The value of the Gaussian NLL after Epoch # 116 is 4.613194320421229
# The value of the Gaussian NLL after Epoch # 117 is 4.613084550223572
# The value of the Gaussian NLL after Epoch # 118 is 4.612979095425943
# The value of the Gaussian NLL after Epoch # 119 is 4.612877743156346
# The value of the Gaussian NLL after Epoch # 120 is 4.612780501540813
# The value of the Gaussian NLL after Epoch # 121 is 4.612686774919499
# The value of the Gaussian NLL after Epoch # 122 is 4.612596636122387
# The value of the Gaussian NLL after Epoch # 123 is 4.612510000108945
# The value of the Gaussian NLL after Epoch # 124 is 4.612426624662869
# The value of the Gaussian NLL after Epoch # 125 is 4.612346241150091
# The value of the Gaussian NLL after Epoch # 126 is 4.6122692505868645
# The value of the Gaussian NLL after Epoch # 127 is 4.612194957155521
# The value of the Gaussian NLL after Epoch # 128 is 4.6121234216698355
# The value of the Gaussian NLL after Epoch # 129 is 4.612054645197619
# The value of the Gaussian NLL after Epoch # 130 is 4.611988077257988
# The value of the Gaussian NLL after Epoch # 131 is 4.611924055589213
# The value of the Gaussian NLL after Epoch # 132 is 4.611862274140527
# The value of the Gaussian NLL after Epoch # 133 is 4.6118026739591365
# The value of the Gaussian NLL after Epoch # 134 is 4.611745131413703
# The value of the Gaussian NLL after Epoch # 135 is 4.611689572002139
# The value of the Gaussian NLL after Epoch # 136 is 4.611635812917127
# The value of the Gaussian NLL after Epoch # 137 is 4.61158392088708
# The value of the Gaussian NLL after Epoch # 138 is 4.61153381270796
# The value of the Gaussian NLL after Epoch # 139 is 4.611485344371083
# The value of the Gaussian NLL after Epoch # 140 is 4.611438373240154
# The value of the Gaussian NLL after Epoch # 141 is 4.611393006302899
# The value of the Gaussian NLL after Epoch # 142 is 4.61134931338365
# The value of the Gaussian NLL after Epoch # 143 is 4.611307152113933
# The value of the Gaussian NLL after Epoch # 144 is 4.611266163806377
# The value of the Gaussian NLL after Epoch # 145 is 4.6112264875207085
# The value of the Gaussian NLL after Epoch # 146 is 4.611187995283463
# The value of the Gaussian NLL after Epoch # 147 is 4.6111506877609285
# The value of the Gaussian NLL after Epoch # 148 is 4.611114530133269
# The value of the Gaussian NLL after Epoch # 149 is 4.611079443914414
# The value of the Gaussian NLL after Epoch # 150 is 4.611045324398953
# The value of the Gaussian NLL after Epoch # 151 is 4.611012239884795
# The value of the Gaussian NLL after Epoch # 152 is 4.610980068280104
# The value of the Gaussian NLL after Epoch # 153 is 4.610948760689385
# The value of the Gaussian NLL after Epoch # 154 is 4.610918353136327
# The value of the Gaussian NLL after Epoch # 155 is 4.610888649150818
# The value of the Gaussian NLL after Epoch # 156 is 4.610859816056858
# The value of the Gaussian NLL after Epoch # 157 is 4.610831831005379
# The value of the Gaussian NLL after Epoch # 158 is 4.6108044066766505
# The value of the Gaussian NLL after Epoch # 159 is 4.610777839501132
# The value of the Gaussian NLL after Epoch # 160 is 4.610751825060505
# The value of the Gaussian NLL after Epoch # 161 is 4.610726456379267
# The value of the Gaussian NLL after Epoch # 162 is 4.610701697171679
# The value of the Gaussian NLL after Epoch # 163 is 4.610677613563402
# The value of the Gaussian NLL after Epoch # 164 is 4.610653989994895
# The value of the Gaussian NLL after Epoch # 165 is 4.610630878204099
# The value of the Gaussian NLL after Epoch # 166 is 4.61060853007313
# The value of the Gaussian NLL after Epoch # 167 is 4.610586744769097
# The value of the Gaussian NLL after Epoch # 168 is 4.610565367703905
# The value of the Gaussian NLL after Epoch # 169 is 4.610544417392
# The value of the Gaussian NLL after Epoch # 170 is 4.610523972307194
# The value of the Gaussian NLL after Epoch # 171 is 4.610503905394707
# The value of the Gaussian NLL after Epoch # 172 is 4.610484261721503
# The value of the Gaussian NLL after Epoch # 173 is 4.610464983474554
# The value of the Gaussian NLL after Epoch # 174 is 4.610446055978916
# The value of the Gaussian NLL after Epoch # 175 is 4.610427508246909
# The value of the Gaussian NLL after Epoch # 176 is 4.610409214010987
# The value of the Gaussian NLL after Epoch # 177 is 4.6103913238678516
# The value of the Gaussian NLL after Epoch # 178 is 4.610373668754706
# The value of the Gaussian NLL after Epoch # 179 is 4.610356399083039
# The value of the Gaussian NLL after Epoch # 180 is 4.610339390201328
# The value of the Gaussian NLL after Epoch # 181 is 4.610322543296142
# The value of the Gaussian NLL after Epoch # 182 is 4.610306069572613
# The value of the Gaussian NLL after Epoch # 183 is 4.610289827207143
# The value of the Gaussian NLL after Epoch # 184 is 4.61027378674691
# The value of the Gaussian NLL after Epoch # 185 is 4.610258031236593
# The value of the Gaussian NLL after Epoch # 186 is 4.61024242841794
# The value of the Gaussian NLL after Epoch # 187 is 4.610227078059948
# The value of the Gaussian NLL after Epoch # 188 is 4.610211813762969
# The value of the Gaussian NLL after Epoch # 189 is 4.610196935037345
# The value of the Gaussian NLL after Epoch # 190 is 4.6101821796164355
# The value of the Gaussian NLL after Epoch # 191 is 4.61016745956526
# The value of the Gaussian NLL after Epoch # 192 is 4.61015304734258
# The value of the Gaussian NLL after Epoch # 193 is 4.610138726946698
# The value of the Gaussian NLL after Epoch # 194 is 4.610124642751367
# The value of the Gaussian NLL after Epoch # 195 is 4.6101106267900045
# The value of the Gaussian NLL after Epoch # 196 is 4.610096842059662
# The value of the Gaussian NLL after Epoch # 197 is 4.610083114150267
# The value of the Gaussian NLL after Epoch # 198 is 4.6100695376553595
# The value of the Gaussian NLL after Epoch # 199 is 4.610056091758609
# The value of the Gaussian NLL after Epoch # 200 is 4.610042680476452
# The value of the Gaussian NLL after Epoch # 201 is 4.6100295270561125
# The value of the Gaussian NLL after Epoch # 202 is 4.610016510840841
# The value of the Gaussian NLL after Epoch # 203 is 4.6100034391462055
# The value of the Gaussian NLL after Epoch # 204 is 4.609990638777479
# The value of the Gaussian NLL after Epoch # 205 is 4.6099777794128505
# The value of the Gaussian NLL after Epoch # 206 is 4.609965138198923
# The value of the Gaussian NLL after Epoch # 207 is 4.609952428865115
# The value of the Gaussian NLL after Epoch # 208 is 4.609939934680306
# The value of the Gaussian NLL after Epoch # 209 is 4.609927594954458
# The value of the Gaussian NLL after Epoch # 210 is 4.609915226728053
# The value of the Gaussian NLL after Epoch # 211 is 4.60990290702373
# The value of the Gaussian NLL after Epoch # 212 is 4.609890722564494
# The value of the Gaussian NLL after Epoch # 213 is 4.609878559328385
# The value of the Gaussian NLL after Epoch # 214 is 4.609866425751391
# The value of the Gaussian NLL after Epoch # 215 is 4.609854443212397
# The value of the Gaussian NLL after Epoch # 216 is 4.609842591324726
# The value of the Gaussian NLL after Epoch # 217 is 4.609830672288348
# The value of the Gaussian NLL after Epoch # 218 is 4.609818832368904
# The value of the Gaussian NLL after Epoch # 219 is 4.609807045916532
# The value of the Gaussian NLL after Epoch # 220 is 4.609795312020164
# The value of the Gaussian NLL after Epoch # 221 is 4.609783945889922
# The value of the Gaussian NLL after Epoch # 222 is 4.609772483096353
# The value of the Gaussian NLL after Epoch # 223 is 4.60976120259916
# The value of the Gaussian NLL after Epoch # 224 is 4.609749843346
# The value of the Gaussian NLL after Epoch # 225 is 4.609738733682968
# The value of the Gaussian NLL after Epoch # 226 is 4.609727440582996
# The value of the Gaussian NLL after Epoch # 227 is 4.609716302287874
# The value of the Gaussian NLL after Epoch # 228 is 4.609705195315059
# The value of the Gaussian NLL after Epoch # 229 is 4.60969403549877
# The value of the Gaussian NLL after Epoch # 230 is 4.609683038423296
# The value of the Gaussian NLL after Epoch # 231 is 4.609672011835916
# The value of the Gaussian NLL after Epoch # 232 is 4.609661043654775
# The value of the Gaussian NLL after Epoch # 233 is 4.609650108840425
# The value of the Gaussian NLL after Epoch # 234 is 4.609639039638071
# The value of the Gaussian NLL after Epoch # 235 is 4.609628184587473
# The value of the Gaussian NLL after Epoch # 236 is 4.609617292612624
# The value of the Gaussian NLL after Epoch # 237 is 4.6096064663925995
# The value of the Gaussian NLL after Epoch # 238 is 4.609595681020321
# The value of the Gaussian NLL after Epoch # 239 is 4.60958489173054
# The value of the Gaussian NLL after Epoch # 240 is 4.609573984967331
# The value of the Gaussian NLL after Epoch # 241 is 4.6095632851803705
# The value of the Gaussian NLL after Epoch # 242 is 4.609552555812476
# The value of the Gaussian NLL after Epoch # 243 is 4.609541782073001
# The value of the Gaussian NLL after Epoch # 244 is 4.609531184277946
# The value of the Gaussian NLL after Epoch # 245 is 4.609520373869019
# The value of the Gaussian NLL after Epoch # 246 is 4.609509719958666
# The value of the Gaussian NLL after Epoch # 247 is 4.60949915784363
# The value of the Gaussian NLL after Epoch # 248 is 4.609488460883212
# The value of the Gaussian NLL after Epoch # 249 is 4.609477806400687
# The value of the Gaussian NLL after Epoch # 250 is 4.609467218466053
# The value of the Gaussian NLL after Epoch # 251 is 4.609456731177579
# The value of the Gaussian NLL after Epoch # 252 is 4.609446127959225
# The value of the Gaussian NLL after Epoch # 253 is 4.6094355217232374
# The value of the Gaussian NLL after Epoch # 254 is 4.609424922294543
# The value of the Gaussian NLL after Epoch # 255 is 4.609414353724702
# The value of the Gaussian NLL after Epoch # 256 is 4.609403924888337
# The value of the Gaussian NLL after Epoch # 257 is 4.609393413258088
# The value of the Gaussian NLL after Epoch # 258 is 4.60938287316604
# The value of the Gaussian NLL after Epoch # 259 is 4.609372427737136
# The value of the Gaussian NLL after Epoch # 260 is 4.609361874589337
# The value of the Gaussian NLL after Epoch # 261 is 4.609351371227752
# The value of the Gaussian NLL after Epoch # 262 is 4.609340927602788
# The value of the Gaussian NLL after Epoch # 263 is 4.609330474820191
# The value of the Gaussian NLL after Epoch # 264 is 4.609320002572845
# The value of the Gaussian NLL after Epoch # 265 is 4.609309520842849
# The value of the Gaussian NLL after Epoch # 266 is 4.6092991224047255
# The value of the Gaussian NLL after Epoch # 267 is 4.609288679803365
# The value of the Gaussian NLL after Epoch # 268 is 4.609278217081632
# The value of the Gaussian NLL after Epoch # 269 is 4.609267809155743
# The value of the Gaussian NLL after Epoch # 270 is 4.609257336287385
# The value of the Gaussian NLL after Epoch # 271 is 4.609246986695237
# The value of the Gaussian NLL after Epoch # 272 is 4.609236616424656
# The value of the Gaussian NLL after Epoch # 273 is 4.609226221570129
# The value of the Gaussian NLL after Epoch # 274 is 4.609215826182951
# The value of the Gaussian NLL after Epoch # 275 is 4.609205385579052
# The value of the Gaussian NLL after Epoch # 276 is 4.6091949785602155
# The value of the Gaussian NLL after Epoch # 277 is 4.60918465981209
# The value of the Gaussian NLL after Epoch # 278 is 4.609174340087521
# The value of the Gaussian NLL after Epoch # 279 is 4.609163960802733
# The value of the Gaussian NLL after Epoch # 280 is 4.609153580339125
# The value of the Gaussian NLL after Epoch # 281 is 4.609143208833317
# The value of the Gaussian NLL after Epoch # 282 is 4.609132787739176
# The value of the Gaussian NLL after Epoch # 283 is 4.609122454390448
# The value of the Gaussian NLL after Epoch # 284 is 4.609112085148985
# The value of the Gaussian NLL after Epoch # 285 is 4.609101779396014
# The value of the Gaussian NLL after Epoch # 286 is 4.6090914134975725
# The value of the Gaussian NLL after Epoch # 287 is 4.60908104580286
# The value of the Gaussian NLL after Epoch # 288 is 4.609070741382588
# The value of the Gaussian NLL after Epoch # 289 is 4.609060441763101
# The value of the Gaussian NLL after Epoch # 290 is 4.609050095500573
# The value of the Gaussian NLL after Epoch # 291 is 4.609039674943522
# The value of the Gaussian NLL after Epoch # 292 is 4.6090293517682195
# The value of the Gaussian NLL after Epoch # 293 is 4.609019070989181
# The value of the Gaussian NLL after Epoch # 294 is 4.609008818779715
# The value of the Gaussian NLL after Epoch # 295 is 4.60899845771977
# The value of the Gaussian NLL after Epoch # 296 is 4.608988114830596
# The value of the Gaussian NLL after Epoch # 297 is 4.608977800359639
# The value of the Gaussian NLL after Epoch # 298 is 4.6089675142584134
# The value of the Gaussian NLL after Epoch # 299 is 4.6089572118244995
# The value of the Gaussian NLL after Epoch # 300 is 4.608946800304117
# The value of the Gaussian NLL after Epoch # 301 is 4.608936530348295
# The value of the Gaussian NLL after Epoch # 302 is 4.608926164914222
# The value of the Gaussian NLL after Epoch # 303 is 4.608915872275878
# The value of the Gaussian NLL after Epoch # 304 is 4.608905607728504
# The value of the Gaussian NLL after Epoch # 305 is 4.608895357563433
# The value of the Gaussian NLL after Epoch # 306 is 4.608884943065978
# The value of the Gaussian NLL after Epoch # 307 is 4.6088747145567925
# The value of the Gaussian NLL after Epoch # 308 is 4.608864307982182
# The value of the Gaussian NLL after Epoch # 309 is 4.608854076985979
# The value of the Gaussian NLL after Epoch # 310 is 4.608843736522222
# The value of the Gaussian NLL after Epoch # 311 is 4.608833513253189
# The value of the Gaussian NLL after Epoch # 312 is 4.608823125411593
# The value of the Gaussian NLL after Epoch # 313 is 4.608812909747537
# The value of the Gaussian NLL after Epoch # 314 is 4.608802642791422
# The value of the Gaussian NLL after Epoch # 315 is 4.608792321268715
# The value of the Gaussian NLL after Epoch # 316 is 4.608781934795952
# The value of the Gaussian NLL after Epoch # 317 is 4.608771644612947
# The value of the Gaussian NLL after Epoch # 318 is 4.608761413147658
# The value of the Gaussian NLL after Epoch # 319 is 4.60875104800702
# The value of the Gaussian NLL after Epoch # 320 is 4.608740779066761
# The value of the Gaussian NLL after Epoch # 321 is 4.608730489754324
# The value of the Gaussian NLL after Epoch # 322 is 4.608720214377227
# The value of the Gaussian NLL after Epoch # 323 is 4.608709918595092
# The value of the Gaussian NLL after Epoch # 324 is 4.608699605545236
# The value of the Gaussian NLL after Epoch # 325 is 4.608689316756414
# The value of the Gaussian NLL after Epoch # 326 is 4.608679031429667
# The value of the Gaussian NLL after Epoch # 327 is 4.608668759937767
# The value of the Gaussian NLL after Epoch # 328 is 4.608658512663462
# The value of the Gaussian NLL after Epoch # 329 is 4.608648086799742
# The value of the Gaussian NLL after Epoch # 330 is 4.608637901437897
# The value of the Gaussian NLL after Epoch # 331 is 4.608627503133074
# The value of the Gaussian NLL after Epoch # 332 is 4.608617300573445
# The value of the Gaussian NLL after Epoch # 333 is 4.608606929761487
# The value of the Gaussian NLL after Epoch # 334 is 4.608596754660505
# The value of the Gaussian NLL after Epoch # 335 is 4.60858645600809
# The value of the Gaussian NLL after Epoch # 336 is 4.608576126319616
# The value of the Gaussian NLL after Epoch # 337 is 4.60856581030808
# The value of the Gaussian NLL after Epoch # 338 is 4.608555542270364
# The value of the Gaussian NLL after Epoch # 339 is 4.6085452535667395
# The value of the Gaussian NLL after Epoch # 340 is 4.608534944184499
# The value of the Gaussian NLL after Epoch # 341 is 4.608524682730891
# The value of the Gaussian NLL after Epoch # 342 is 4.608514434880085
# The value of the Gaussian NLL after Epoch # 343 is 4.608504108124765
# The value of the Gaussian NLL after Epoch # 344 is 4.60849383969422
# The value of the Gaussian NLL after Epoch # 345 is 4.6084835057838776
# The value of the Gaussian NLL after Epoch # 346 is 4.608473264480487
# The value of the Gaussian NLL after Epoch # 347 is 4.60846294424348
# The value of the Gaussian NLL after Epoch # 348 is 4.608452671848715
# The value of the Gaussian NLL after Epoch # 349 is 4.608442310063394
# The value of the Gaussian NLL after Epoch # 350 is 4.608431996094549
# The value of the Gaussian NLL after Epoch # 351 is 4.608421795573534
# The value of the Gaussian NLL after Epoch # 352 is 4.6084115637936955
# The value of the Gaussian NLL after Epoch # 353 is 4.608401129231256
# The value of the Gaussian NLL after Epoch # 354 is 4.608390945303086
# The value of the Gaussian NLL after Epoch # 355 is 4.608380671933736
# The value of the Gaussian NLL after Epoch # 356 is 4.608370377715293
# The value of the Gaussian NLL after Epoch # 357 is 4.608360073095947
# The value of the Gaussian NLL after Epoch # 358 is 4.608349758070429
# The value of the Gaussian NLL after Epoch # 359 is 4.608339501227898
# The value of the Gaussian NLL after Epoch # 360 is 4.60832919966946
# The value of the Gaussian NLL after Epoch # 361 is 4.608318921983644
# The value of the Gaussian NLL after Epoch # 362 is 4.608308599573062
# The value of the Gaussian NLL after Epoch # 363 is 4.608298348674081
# The value of the Gaussian NLL after Epoch # 364 is 4.608288063502908
# The value of the Gaussian NLL after Epoch # 365 is 4.608277836468174
# The value of the Gaussian NLL after Epoch # 366 is 4.608267451333207
# The value of the Gaussian NLL after Epoch # 367 is 4.608257192904753
# The value of the Gaussian NLL after Epoch # 368 is 4.608246944960543
# The value of the Gaussian NLL after Epoch # 369 is 4.608236586531165
# The value of the Gaussian NLL after Epoch # 370 is 4.608226307161365
# The value of the Gaussian NLL after Epoch # 371 is 4.608216006828451
# The value of the Gaussian NLL after Epoch # 372 is 4.608205775066026
# The value of the Gaussian NLL after Epoch # 373 is 4.608195509007917
# The value of the Gaussian NLL after Epoch # 374 is 4.608185290543
# The value of the Gaussian NLL after Epoch # 375 is 4.608174969204445
# The value of the Gaussian NLL after Epoch # 376 is 4.608164616385536
# The value of the Gaussian NLL after Epoch # 377 is 4.608154263545905
# The value of the Gaussian NLL after Epoch # 378 is 4.6081440240294365
# The value of the Gaussian NLL after Epoch # 379 is 4.608133763502988
# The value of the Gaussian NLL after Epoch # 380 is 4.608123502948641
# The value of the Gaussian NLL after Epoch # 381 is 4.608113210875614
# The value of the Gaussian NLL after Epoch # 382 is 4.608102884485004
# The value of the Gaussian NLL after Epoch # 383 is 4.608092523778933
# The value of the Gaussian NLL after Epoch # 384 is 4.608082358215189
# The value of the Gaussian NLL after Epoch # 385 is 4.608072044988329
# The value of the Gaussian NLL after Epoch # 386 is 4.608061731719182
# The value of the Gaussian NLL after Epoch # 387 is 4.608051397396913
# The value of the Gaussian NLL after Epoch # 388 is 4.608041142087044
# The value of the Gaussian NLL after Epoch # 389 is 4.608030876221081
# The value of the Gaussian NLL after Epoch # 390 is 4.608020668345522
# The value of the Gaussian NLL after Epoch # 391 is 4.608010268018805
# The value of the Gaussian NLL after Epoch # 392 is 4.607999980971459
# The value of the Gaussian NLL after Epoch # 393 is 4.607989672840756
# The value of the Gaussian NLL after Epoch # 394 is 4.607979512253472
# The value of the Gaussian NLL after Epoch # 395 is 4.607969203998258
# The value of the Gaussian NLL after Epoch # 396 is 4.607958908917441
# The value of the Gaussian NLL after Epoch # 397 is 4.607948534708792
# The value of the Gaussian NLL after Epoch # 398 is 4.607938239491719
# The value of the Gaussian NLL after Epoch # 399 is 4.607927978475445
# The value of the Gaussian NLL after Epoch # 400 is 4.607917730612298
# The value of the Gaussian NLL after Epoch # 401 is 4.607907414137871
# The value of the Gaussian NLL after Epoch # 402 is 4.6078971661238315
# The value of the Gaussian NLL after Epoch # 403 is 4.607886873240893
# The value of the Gaussian NLL after Epoch # 404 is 4.607876490694076
# The value of the Gaussian NLL after Epoch # 405 is 4.607866221391108
# The value of the Gaussian NLL after Epoch # 406 is 4.607855986270983
# The value of the Gaussian NLL after Epoch # 407 is 4.607845751068261
# The value of the Gaussian NLL after Epoch # 408 is 4.607835368199592
# The value of the Gaussian NLL after Epoch # 409 is 4.607825111765076
# The value of the Gaussian NLL after Epoch # 410 is 4.607814707662853
# The value of the Gaussian NLL after Epoch # 411 is 4.6078044853153575
# The value of the Gaussian NLL after Epoch # 412 is 4.607794262878921
# The value of the Gaussian NLL after Epoch # 413 is 4.607783961296373
# The value of the Gaussian NLL after Epoch # 414 is 4.607773604286523
# The value of the Gaussian NLL after Epoch # 415 is 4.607763326241465
# The value of the Gaussian NLL after Epoch # 416 is 4.6077531508749905
# The value of the Gaussian NLL after Epoch # 417 is 4.6077427593304865
# The value of the Gaussian NLL after Epoch # 418 is 4.607732515262719
# The value of the Gaussian NLL after Epoch # 419 is 4.607722205207874
# The value of the Gaussian NLL after Epoch # 420 is 4.607711895053584
# The value of the Gaussian NLL after Epoch # 421 is 4.607701698108701
# The value of the Gaussian NLL after Epoch # 422 is 4.607691353501843
# The value of the Gaussian NLL after Epoch # 423 is 4.607680974544927
# The value of the Gaussian NLL after Epoch # 424 is 4.607670743048765
# The value of the Gaussian NLL after Epoch # 425 is 4.607660400738902
# The value of the Gaussian NLL after Epoch # 426 is 4.607650147931128
# The value of the Gaussian NLL after Epoch # 427 is 4.607639850214192
# The value of the Gaussian NLL after Epoch # 428 is 4.607629631445447
# The value of the Gaussian NLL after Epoch # 429 is 4.607619265021808
# The value of the Gaussian NLL after Epoch # 430 is 4.607609001236941
# The value of the Gaussian NLL after Epoch # 431 is 4.607598703098878
# The value of the Gaussian NLL after Epoch # 432 is 4.6075883494875445
# The value of the Gaussian NLL after Epoch # 433 is 4.60757814330995
# The value of the Gaussian NLL after Epoch # 434 is 4.607567823724293
# The value of the Gaussian NLL after Epoch # 435 is 4.607557606759547
# The value of the Gaussian NLL after Epoch # 436 is 4.607547252709195
# The value of the Gaussian NLL after Epoch # 437 is 4.607536932792592
# The value of the Gaussian NLL after Epoch # 438 is 4.607526726058366
# The value of the Gaussian NLL after Epoch # 439 is 4.607516361111444
# The value of the Gaussian NLL after Epoch # 440 is 4.607506053964045
# The value of the Gaussian NLL after Epoch # 441 is 4.607495825750819
# The value of the Gaussian NLL after Epoch # 442 is 4.607485552610524
# The value of the Gaussian NLL after Epoch # 443 is 4.6074752003040675
# The value of the Gaussian NLL after Epoch # 444 is 4.6074648584555895
# The value of the Gaussian NLL after Epoch # 445 is 4.607454664014519
# The value of the Gaussian NLL after Epoch # 446 is 4.6074443561718
# The value of the Gaussian NLL after Epoch # 447 is 4.60743403763591
# The value of the Gaussian NLL after Epoch # 448 is 4.607423695326545
# The value of the Gaussian NLL after Epoch # 449 is 4.6074134661839725
# The value of the Gaussian NLL after Epoch # 450 is 4.607403170949619
# The value of the Gaussian NLL after Epoch # 451 is 4.607392865012118
# The value of the Gaussian NLL after Epoch # 452 is 4.607382569534216
# The value of the Gaussian NLL after Epoch # 453 is 4.607372273935084
# The value of the Gaussian NLL after Epoch # 454 is 4.60736205726021
# The value of the Gaussian NLL after Epoch # 455 is 4.607351716602655
# The value of the Gaussian NLL after Epoch # 456 is 4.607341420639176
# The value of the Gaussian NLL after Epoch # 457 is 4.6073311245544994
# The value of the Gaussian NLL after Epoch # 458 is 4.607320749304557
# The value of the Gaussian NLL after Epoch # 459 is 4.60731056624826
# The value of the Gaussian NLL after Epoch # 460 is 4.607300269799334
# The value of the Gaussian NLL after Epoch # 461 is 4.607289973229243
# The value of the Gaussian NLL after Epoch # 462 is 4.607279644757333
# The value of the Gaussian NLL after Epoch # 463 is 4.6072693609764395
# The value of the Gaussian NLL after Epoch # 464 is 4.6072591561107155
# The value of the Gaussian NLL after Epoch # 465 is 4.60724882725687
# The value of the Gaussian NLL after Epoch # 466 is 4.607238508873318
# The value of the Gaussian NLL after Epoch # 467 is 4.607228145544709
# The value of the Gaussian NLL after Epoch # 468 is 4.607217940170954
# The value of the Gaussian NLL after Epoch # 469 is 4.607207610809302
# The value of the Gaussian NLL after Epoch # 470 is 4.607197360359955
# The value of the Gaussian NLL after Epoch # 471 is 4.607187041346073
# The value of the Gaussian NLL after Epoch # 472 is 4.607176711603046
# The value of the Gaussian NLL after Epoch # 473 is 4.607166460771215
# The value of the Gaussian NLL after Epoch # 474 is 4.607156141379101
# The value of the Gaussian NLL after Epoch # 475 is 4.6071458560771426
# The value of the Gaussian NLL after Epoch # 476 is 4.607135604863236
# The value of the Gaussian NLL after Epoch # 477 is 4.607125219052216
# The value of the Gaussian NLL after Epoch # 478 is 4.607114912147875
# The value of the Gaussian NLL after Epoch # 479 is 4.6071046287143815
# The value of the Gaussian NLL after Epoch # 480 is 4.607094355758787
# The value of the Gaussian NLL after Epoch # 481 is 4.607084082671086
# The value of the Gaussian NLL after Epoch # 482 is 4.607073843661761
# The value of the Gaussian NLL after Epoch # 483 is 4.607063457064818
# The value of the Gaussian NLL after Epoch # 484 is 4.607053183581249
# The value of the Gaussian NLL after Epoch # 485 is 4.607042899348551
# The value of the Gaussian NLL after Epoch # 486 is 4.607032591392182
# The value of the Gaussian NLL after Epoch # 487 is 4.607022317512116
# The value of the Gaussian NLL after Epoch # 488 is 4.607012043500003
# The value of the Gaussian NLL after Epoch # 489 is 4.607001690323684
# The value of the Gaussian NLL after Epoch # 490 is 4.6069914160479
# The value of the Gaussian NLL after Epoch # 491 is 4.606981141640095
# The value of the Gaussian NLL after Epoch # 492 is 4.606970856476174
# The value of the Gaussian NLL after Epoch # 493 is 4.60696058180334
# The value of the Gaussian NLL after Epoch # 494 is 4.606950306998509
# The value of the Gaussian NLL after Epoch # 495 is 4.606939963659057
# The value of the Gaussian NLL after Epoch # 496 is 4.606929677963537
# The value of the Gaussian NLL after Epoch # 497 is 4.606919402763164
# The value of the Gaussian NLL after Epoch # 498 is 4.6069091274308285
# The value of the Gaussian NLL after Epoch # 499 is 4.606898807136892
# The value of the Gaussian NLL after Epoch # 500 is 4.606888544473869
# The value of the Gaussian NLL after Epoch # 501 is 4.606878134252045
# The value of the Gaussian NLL after Epoch # 502 is 4.60686793970897
# The value of the Gaussian NLL after Epoch # 503 is 4.606857710830076
# The value of the Gaussian NLL after Epoch # 504 is 4.60684730020153
# The value of the Gaussian NLL after Epoch # 505 is 4.606836992022185
# The value of the Gaussian NLL after Epoch # 506 is 4.606826762730125
# The value of the Gaussian NLL after Epoch # 507 is 4.60681646491364
# The value of the Gaussian NLL after Epoch # 508 is 4.606806122129174
# The value of the Gaussian NLL after Epoch # 509 is 4.606795926615059
# The value of the Gaussian NLL after Epoch # 510 is 4.606785515174436
# The value of the Gaussian NLL after Epoch # 511 is 4.606775285193371
# The value of the Gaussian NLL after Epoch # 512 is 4.606764976051101
# The value of the Gaussian NLL after Epoch # 513 is 4.606754677415886
# The value of the Gaussian NLL after Epoch # 514 is 4.6067444470207315
# The value of the Gaussian NLL after Epoch # 515 is 4.606734103278446
# The value of the Gaussian NLL after Epoch # 516 is 4.606723725213285
# The value of the Gaussian NLL after Epoch # 517 is 4.606713460219417
# The value of the Gaussian NLL after Epoch # 518 is 4.60670319508836
# The value of the Gaussian NLL after Epoch # 519 is 4.606692919169407
# The value of the Gaussian NLL after Epoch # 520 is 4.606682619579296
# The value of the Gaussian NLL after Epoch # 521 is 4.60667227501775
# The value of the Gaussian NLL after Epoch # 522 is 4.606662077702774
# The value of the Gaussian NLL after Epoch # 523 is 4.606651811884629
# The value of the Gaussian NLL after Epoch # 524 is 4.606641432731039
# The value of the Gaussian NLL after Epoch # 525 is 4.606631166639753
# The value of the Gaussian NLL after Epoch # 526 is 4.606620855574289
# The value of the Gaussian NLL after Epoch # 527 is 4.606610555029698
# The value of the Gaussian NLL after Epoch # 528 is 4.606600322705577
# The value of the Gaussian NLL after Epoch # 529 is 4.606589932212442
# The value of the Gaussian NLL after Epoch # 530 is 4.606579631258814
# The value of the Gaussian NLL after Epoch # 531 is 4.6065693985214615
# The value of the Gaussian NLL after Epoch # 532 is 4.606559131470361
# The value of the Gaussian NLL after Epoch # 533 is 4.606548706255127
# The value of the Gaussian NLL after Epoch # 534 is 4.606538404756894
# The value of the Gaussian NLL after Epoch # 535 is 4.606528171469339
# The value of the Gaussian NLL after Epoch # 536 is 4.606517903870885
# The value of the Gaussian NLL after Epoch # 537 is 4.6065075912953315
# The value of the Gaussian NLL after Epoch # 538 is 4.606497244411163
# The value of the Gaussian NLL after Epoch # 539 is 4.606486976401793
# The value of the Gaussian NLL after Epoch # 540 is 4.606476663414533
# The value of the Gaussian NLL after Epoch # 541 is 4.606466395130883
# The value of the Gaussian NLL after Epoch # 542 is 4.606456026354222
# The value of the Gaussian NLL after Epoch # 543 is 4.606445770614318
# The value of the Gaussian NLL after Epoch # 544 is 4.606435504057076
# The value of the Gaussian NLL after Epoch # 545 is 4.606425282197824
# The value of the Gaussian NLL after Epoch # 546 is 4.606414912856269
# The value of the Gaussian NLL after Epoch # 547 is 4.606404577539513
# The value of the Gaussian NLL after Epoch # 548 is 4.6063943552523465
# The value of the Gaussian NLL after Epoch # 549 is 4.606383985488497
# The value of the Gaussian NLL after Epoch # 550 is 4.606373728753344
# The value of the Gaussian NLL after Epoch # 551 is 4.606363427032358
# The value of the Gaussian NLL after Epoch # 552 is 4.606353056846293
# The value of the Gaussian NLL after Epoch # 553 is 4.606342799685463
# The value of the Gaussian NLL after Epoch # 554 is 4.606332565857672
# The value of the Gaussian NLL after Epoch # 555 is 4.606322308410842
# The value of the Gaussian NLL after Epoch # 556 is 4.606311937660226
# The value of the Gaussian NLL after Epoch # 557 is 4.606301714087923
# The value of the Gaussian NLL after Epoch # 558 is 4.606291411369739
# The value of the Gaussian NLL after Epoch # 559 is 4.606281040196381
# The value of the Gaussian NLL after Epoch # 560 is 4.606270782040203
# The value of the Gaussian NLL after Epoch # 561 is 4.606260444740946
# The value of the Gaussian NLL after Epoch # 562 is 4.606250107300494
# The value of the Gaussian NLL after Epoch # 563 is 4.606239882872358
# The value of the Gaussian NLL after Epoch # 564 is 4.606229510995623
# The value of the Gaussian NLL after Epoch # 565 is 4.6062192862823625
# The value of the Gaussian NLL after Epoch # 566 is 4.606208982426941
# The value of the Gaussian NLL after Epoch # 567 is 4.606198610127673
# The value of the Gaussian NLL after Epoch # 568 is 4.6061883508363675
# The value of the Gaussian NLL after Epoch # 569 is 4.606178114853425
# The value of the Gaussian NLL after Epoch # 570 is 4.6061677079824594
# The value of the Gaussian NLL after Epoch # 571 is 4.6061574482652405
# The value of the Gaussian NLL after Epoch # 572 is 4.606147222553132
# The value of the Gaussian NLL after Epoch # 573 is 4.606136838706643
# The value of the Gaussian NLL after Epoch # 574 is 4.606126612708608
# The value of the Gaussian NLL after Epoch # 575 is 4.606116318277133
# The value of the Gaussian NLL after Epoch # 576 is 4.606105978855282
# The value of the Gaussian NLL after Epoch # 577 is 4.606095707579589
# The value of the Gaussian NLL after Epoch # 578 is 4.606085481010312
# The value of the Gaussian NLL after Epoch # 579 is 4.606075072878305
# The value of the Gaussian NLL after Epoch # 580 is 4.60606481188336
# The value of the Gaussian NLL after Epoch # 581 is 4.606054574177041
# The value of the Gaussian NLL after Epoch # 582 is 4.606044233905188
# The value of the Gaussian NLL after Epoch # 583 is 4.606033938343839
# The value of the Gaussian NLL after Epoch # 584 is 4.60602356365152
# The value of the Gaussian NLL after Epoch # 585 is 4.606013336085584
# The value of the Gaussian NLL after Epoch # 586 is 4.6060029845345385
# The value of the Gaussian NLL after Epoch # 587 is 4.605992688409035
# The value of the Gaussian NLL after Epoch # 588 is 4.605982460414813
# The value of the Gaussian NLL after Epoch # 589 is 4.605972198142136
# The value of the Gaussian NLL after Epoch # 590 is 4.60596184602109
# The value of the Gaussian NLL after Epoch # 591 is 4.60595143620939
# The value of the Gaussian NLL after Epoch # 592 is 4.60594120764556
# The value of the Gaussian NLL after Epoch # 593 is 4.605930978938486
# The value of the Gaussian NLL after Epoch # 594 is 4.6059205579847315
# The value of the Gaussian NLL after Epoch # 595 is 4.6059103289927945
# The value of the Gaussian NLL after Epoch # 596 is 4.60590009985764
# The value of the Gaussian NLL after Epoch # 597 is 4.605889757465197
# The value of the Gaussian NLL after Epoch # 598 is 4.605879493915935
# The value of the Gaussian NLL after Epoch # 599 is 4.605869219497559
# The value of the Gaussian NLL after Epoch # 600 is 4.605858876680619
# The value of the Gaussian NLL after Epoch # 601 is 4.605848612705515
# The value of the Gaussian NLL after Epoch # 602 is 4.605838269606403
# The value of the Gaussian NLL after Epoch # 603 is 4.605828039473569
# The value of the Gaussian NLL after Epoch # 604 is 4.605817764340879
# The value of the Gaussian NLL after Epoch # 605 is 4.605807386692769
# The value of the Gaussian NLL after Epoch # 606 is 4.605797043028472
# The value of the Gaussian NLL after Epoch # 607 is 4.6057867782033215
# The value of the Gaussian NLL after Epoch # 608 is 4.605776536622416
# The value of the Gaussian NLL after Epoch # 609 is 4.605766192533153
# The value of the Gaussian NLL after Epoch # 610 is 4.605755893161275
# The value of the Gaussian NLL after Epoch # 611 is 4.605745548790697
# The value of the Gaussian NLL after Epoch # 612 is 4.605735317376036
# The value of the Gaussian NLL after Epoch # 613 is 4.605725040959385
# The value of the Gaussian NLL after Epoch # 614 is 4.605714696163968
# The value of the Gaussian NLL after Epoch # 615 is 4.605704351227812
# The value of the Gaussian NLL after Epoch # 616 is 4.6056941192429655
# The value of the Gaussian NLL after Epoch # 617 is 4.605683774024194
# The value of the Gaussian NLL after Epoch # 618 is 4.605673473524849
# The value of the Gaussian NLL after Epoch # 619 is 4.605663230367168
# The value of the Gaussian NLL after Epoch # 620 is 4.60565285061103
# The value of the Gaussian NLL after Epoch # 621 is 4.605642617914536
# The value of the Gaussian NLL after Epoch # 622 is 4.605632271989956
# The value of the Gaussian NLL after Epoch # 623 is 4.605621925924705
# The value of the Gaussian NLL after Epoch # 624 is 4.605611647939945
# The value of the Gaussian NLL after Epoch # 625 is 4.605601414673576
# The value of the Gaussian NLL after Epoch # 626 is 4.605591068183797
# The value of the Gaussian NLL after Epoch # 627 is 4.605580800524201
# The value of the Gaussian NLL after Epoch # 628 is 4.605570453752697
# The value of the Gaussian NLL after Epoch # 629 is 4.605560209161762
# The value of the Gaussian NLL after Epoch # 630 is 4.605549828000562
# The value of the Gaussian NLL after Epoch # 631 is 4.605539593880468
# The value of the Gaussian NLL after Epoch # 632 is 4.605529280648926
# The value of the Gaussian NLL after Epoch # 633 is 4.605519046243475
# The value of the Gaussian NLL after Epoch # 634 is 4.605508664520402
# The value of the Gaussian NLL after Epoch # 635 is 4.605498419069556
# The value of the Gaussian NLL after Epoch # 636 is 4.605488037065357
# The value of the Gaussian NLL after Epoch # 637 is 4.605477802091146
# The value of the Gaussian NLL after Epoch # 638 is 4.605467453907539
# The value of the Gaussian NLL after Epoch # 639 is 4.605457252748813
# The value of the Gaussian NLL after Epoch # 640 is 4.605446904282283
# The value of the Gaussian NLL after Epoch # 641 is 4.605436623872503
# The value of the Gaussian NLL after Epoch # 642 is 4.605426275123545
# The value of the Gaussian NLL after Epoch # 643 is 4.605416005197597
# The value of the Gaussian NLL after Epoch # 644 is 4.60540565616719
# The value of the Gaussian NLL after Epoch # 645 is 4.605395454150547
# The value of the Gaussian NLL after Epoch # 646 is 4.60538510483732
# The value of the Gaussian NLL after Epoch # 647 is 4.60537483434532
# The value of the Gaussian NLL after Epoch # 648 is 4.605364508070629
# The value of the Gaussian NLL after Epoch # 649 is 4.605354237294697
# The value of the Gaussian NLL after Epoch # 650 is 4.605343887417096
# The value of the Gaussian NLL after Epoch # 651 is 4.605333650450536
# The value of the Gaussian NLL after Epoch # 652 is 4.605323266200015
# The value of the Gaussian NLL after Epoch # 653 is 4.605312949990894
# The value of the Gaussian NLL after Epoch # 654 is 4.605302712598456
# The value of the Gaussian NLL after Epoch # 655 is 4.605292317147234
# The value of the Gaussian NLL after Epoch # 656 is 4.605282113558381
# The value of the Gaussian NLL after Epoch # 657 is 4.605271796780914
# The value of the Gaussian NLL after Epoch # 658 is 4.605261524731642
# The value of the Gaussian NLL after Epoch # 659 is 4.605251173584885
# The value of the Gaussian NLL after Epoch # 660 is 4.605240856383065
# The value of the Gaussian NLL after Epoch # 661 is 4.605230573124083
# The value of the Gaussian NLL after Epoch # 662 is 4.605220221554189
# The value of the Gaussian NLL after Epoch # 663 is 4.605209982881522
# The value of the Gaussian NLL after Epoch # 664 is 4.60519963102982
# The value of the Gaussian NLL after Epoch # 665 is 4.605189426154825
# The value of the Gaussian NLL after Epoch # 666 is 4.605179074020649
# The value of the Gaussian NLL after Epoch # 667 is 4.605168721746178
# The value of the Gaussian NLL after Epoch # 668 is 4.605158482363191
# The value of the Gaussian NLL after Epoch # 669 is 4.605148119013303
# The value of the Gaussian NLL after Epoch # 670 is 4.6051378793453415
# The value of the Gaussian NLL after Epoch # 671 is 4.6051275605840845
# The value of the Gaussian NLL after Epoch # 672 is 4.6051172865545755
# The value of the Gaussian NLL after Epoch # 673 is 4.6051069675102605
# The value of the Gaussian NLL after Epoch # 674 is 4.605096761349126
# The value of the Gaussian NLL after Epoch # 675 is 4.605086373870871
# The value of the Gaussian NLL after Epoch # 676 is 4.6050760544019145
# The value of the Gaussian NLL after Epoch # 677 is 4.6050657688647005
# The value of the Gaussian NLL after Epoch # 678 is 4.6050554491118305
# The value of the Gaussian NLL after Epoch # 679 is 4.605045242236384
# The value of the Gaussian NLL after Epoch # 680 is 4.6050348540566794
# The value of the Gaussian NLL after Epoch # 681 is 4.6050245338792966
# The value of the Gaussian NLL after Epoch # 682 is 4.605014326575889
# The value of the Gaussian NLL after Epoch # 683 is 4.605003937975936
# The value of the Gaussian NLL after Epoch # 684 is 4.604993617374118
# The value of the Gaussian NLL after Epoch # 685 is 4.604983409642827
# The value of the Gaussian NLL after Epoch # 686 is 4.604973020622704
# The value of the Gaussian NLL after Epoch # 687 is 4.604962767729196
# The value of the Gaussian NLL after Epoch # 688 is 4.6049524124944705
# The value of the Gaussian NLL after Epoch # 689 is 4.604942091184571
# The value of the Gaussian NLL after Epoch # 690 is 4.604931848675217
# The value of the Gaussian NLL after Epoch # 691 is 4.604921527081869
# The value of the Gaussian NLL after Epoch # 692 is 4.604911205347041
# The value of the Gaussian NLL after Epoch # 693 is 4.604900928349291
# The value of the Gaussian NLL after Epoch # 694 is 4.604890606331767
# The value of the Gaussian NLL after Epoch # 695 is 4.6048803971732735
# The value of the Gaussian NLL after Epoch # 696 is 4.60487004081167
# The value of the Gaussian NLL after Epoch # 697 is 4.604859718369346
# ...
# The value of the Gaussian NLL after Epoch # 88056 is 4.142496380937779
# The value of the Gaussian NLL after Epoch # 88057 is 4.14249616029746
# The value of the Gaussian NLL after Epoch # 88058 is 4.1424960648297855
# The value of the Gaussian NLL after Epoch # 88059 is 4.1424959125707055
# The value of the Gaussian NLL after Epoch # 88060 is 4.142495709041212
# The value of the Gaussian NLL after Epoch # 88061 is 4.14249561359206
# The value of the Gaussian NLL after Epoch # 88062 is 4.1424954613516585
# The value of the Gaussian NLL after Epoch # 88063 is 4.1424952947855775
# The value of the Gaussian NLL after Epoch # 88064 is 4.142495142557633
# The value of the Gaussian NLL after Epoch # 88065 is 4.142494993096177
# The value of the Gaussian NLL after Epoch # 88066 is 4.142494826548654
# The value of the Gaussian NLL after Epoch # 88067 is 4.142494674339371
# The value of the Gaussian NLL after Epoch # 88068 is 4.1424945248964855
# The value of the Gaussian NLL after Epoch # 88069 is 4.1424943726996775
# The value of the Gaussian NLL after Epoch # 88070 is 4.142494223269179
# The value of the Gaussian NLL after Epoch # 88071 is 4.142494056752582
# The value of the Gaussian NLL after Epoch # 88072 is 4.142493961371333
# The value of the Gaussian NLL after Epoch # 88073 is 4.142493809199374
# The value of the Gaussian NLL after Epoch # 88074 is 4.142493657033686
# The value of the Gaussian NLL after Epoch # 88075 is 4.142493436504985
# The value of the Gaussian NLL after Epoch # 88076 is 4.142493287111628
# The value of the Gaussian NLL after Epoch # 88077 is 4.142493137724455
# The value of the Gaussian NLL after Epoch # 88078 is 4.14249298558365
# The value of the Gaussian NLL after Epoch # 88079 is 4.142492819116536
# The value of the Gaussian NLL after Epoch # 88080 is 4.142492723784686
# The value of the Gaussian NLL after Epoch # 88081 is 4.142492571662525
# The value of the Gaussian NLL after Epoch # 88082 is 4.142492351177235
# The value of the Gaussian NLL after Epoch # 88083 is 4.14249219906755
# The value of the Gaussian NLL after Epoch # 88084 is 4.142491995687039
# The value of the Gaussian NLL after Epoch # 88085 is 4.14249197151511
# The value of the Gaussian NLL after Epoch # 88086 is 4.142491733962265
# The value of the Gaussian NLL after Epoch # 88087 is 4.1424915818774455
# The value of the Gaussian NLL after Epoch # 88088 is 4.142491503687367
# The value of the Gaussian NLL after Epoch # 88089 is 4.142491351615022
# The value of the Gaussian NLL after Epoch # 88090 is 4.142491114086957
# The value of the Gaussian NLL after Epoch # 88091 is 4.142490981878845
# The value of the Gaussian NLL after Epoch # 88092 is 4.142490886621084
# The value of the Gaussian NLL after Epoch # 88093 is 4.142490734573604
# The value of the Gaussian NLL after Epoch # 88094 is 4.142490582532395
# The value of the Gaussian NLL after Epoch # 88095 is 4.142490416164232
# The value of the Gaussian NLL after Epoch # 88096 is 4.142490266894677
# The value of the Gaussian NLL after Epoch # 88097 is 4.142490100538882
# The value of the Gaussian NLL after Epoch # 88098 is 4.142489948522524
# The value of the Gaussian NLL after Epoch # 88099 is 4.142489796512434
# The value of the Gaussian NLL after Epoch # 88100 is 4.142489647267653
# The value of the Gaussian NLL after Epoch # 88101 is 4.1424894980290565
# The value of the Gaussian NLL after Epoch # 88102 is 4.1424893317041915
# The value of the Gaussian NLL after Epoch # 88103 is 4.142489179718969
# The value of the Gaussian NLL after Epoch # 88104 is 4.142489030498944
# The value of the Gaussian NLL after Epoch # 88105 is 4.142488864192635
# The value of the Gaussian NLL after Epoch # 88106 is 4.142488712226076
# The value of the Gaussian NLL after Epoch # 88107 is 4.142488563024622
# The value of the Gaussian NLL after Epoch # 88108 is 4.142488413829352
# The value of the Gaussian NLL after Epoch # 88109 is 4.1424882618814705
# The value of the Gaussian NLL after Epoch # 88110 is 4.1424881667348465
# The value of the Gaussian NLL after Epoch # 88111 is 4.142488014799423
# The value of the Gaussian NLL after Epoch # 88112 is 4.142487794500174
# The value of the Gaussian NLL after Epoch # 88113 is 4.142487699372072
# The value of the Gaussian NLL after Epoch # 88114 is 4.142487547455311
# The value of the Gaussian NLL after Epoch # 88115 is 4.142487381210843
# The value of the Gaussian NLL after Epoch # 88116 is 4.14248722930654
# The value of the Gaussian NLL after Epoch # 88117 is 4.142487026130849
# The value of the Gaussian NLL after Epoch # 88118 is 4.142486931033624
# The value of the Gaussian NLL after Epoch # 88119 is 4.142486764813898
# The value of the Gaussian NLL after Epoch # 88120 is 4.142486612934461
# The value of the Gaussian NLL after Epoch # 88121 is 4.142486463819667
# The value of the Gaussian NLL after Epoch # 88122 is 4.142486297618499
# The value of the Gaussian NLL after Epoch # 88123 is 4.142486145757725
# The value of the Gaussian NLL after Epoch # 88124 is 4.14248599390322
# The value of the Gaussian NLL after Epoch # 88125 is 4.142485790777192
# The value of the Gaussian NLL after Epoch # 88126 is 4.142485766857958
# The value of the Gaussian NLL after Epoch # 88127 is 4.14248552955913
# The value of the Gaussian NLL after Epoch # 88128 is 4.142485377729492
# The value of the Gaussian NLL after Epoch # 88129 is 4.14248522866423
# The value of the Gaussian NLL after Epoch # 88130 is 4.142485062512549
# The value of the Gaussian NLL after Epoch # 88131 is 4.142484910701574
# The value of the Gaussian NLL after Epoch # 88132 is 4.142484815690781
# The value of the Gaussian NLL after Epoch # 88133 is 4.142484663892265
# The value of the Gaussian NLL after Epoch # 88134 is 4.142484531950587
# The value of the Gaussian NLL after Epoch # 88135 is 4.1424842406654845
# The value of the Gaussian NLL after Epoch # 88136 is 4.142484216807866
# The value of the Gaussian NLL after Epoch # 88137 is 4.142484065034234
# The value of the Gaussian NLL after Epoch # 88138 is 4.14248391326687
# The value of the Gaussian NLL after Epoch # 88139 is 4.142483676042397
# The value of the Gaussian NLL after Epoch # 88140 is 4.142483598173672
# The value of the Gaussian NLL after Epoch # 88141 is 4.142483446424972
# The value of the Gaussian NLL after Epoch # 88142 is 4.142483297440188
# The value of the Gaussian NLL after Epoch # 88143 is 4.142483077333188
# The value of the Gaussian NLL after Epoch # 88144 is 4.142482925603167
# The value of the Gaussian NLL after Epoch # 88145 is 4.142482830672655
# The value of the Gaussian NLL after Epoch # 88146 is 4.142482664619929
# The value of the Gaussian NLL after Epoch # 88147 is 4.142482512908555
# The value of the Gaussian NLL after Epoch # 88148 is 4.142482363960916
# The value of the Gaussian NLL after Epoch # 88149 is 4.142482212262016
# The value of the Gaussian NLL after Epoch # 88150 is 4.142482063326765
# The value of the Gaussian NLL after Epoch # 88151 is 4.142481914397701
# The value of the Gaussian NLL after Epoch # 88152 is 4.142481748382088
# The value of the Gaussian NLL after Epoch # 88153 is 4.142481596708055
# The value of the Gaussian NLL after Epoch # 88154 is 4.142481501833097
# The value of the Gaussian NLL after Epoch # 88155 is 4.142481350171523
# The value of the Gaussian NLL after Epoch # 88156 is 4.142481130145137
# The value of the Gaussian NLL after Epoch # 88157 is 4.142480981253217
# The value of the Gaussian NLL after Epoch # 88158 is 4.142480886402951
# The value of the Gaussian NLL after Epoch # 88159 is 4.142480734766243
# The value of the Gaussian NLL after Epoch # 88160 is 4.142480583135807
# The value of the Gaussian NLL after Epoch # 88161 is 4.142480363140434
# The value of the Gaussian NLL after Epoch # 88162 is 4.14248026831488
# The value of the Gaussian NLL after Epoch # 88163 is 4.142480116703105
# The value of the Gaussian NLL after Epoch # 88164 is 4.142479896726339
# The value of the Gaussian NLL after Epoch # 88165 is 4.142479747883953
# The value of the Gaussian NLL after Epoch # 88166 is 4.1424796530830905
# The value of the Gaussian NLL after Epoch # 88167 is 4.142479501496184
# The value of the Gaussian NLL after Epoch # 88168 is 4.142479349915548
# The value of the Gaussian NLL after Epoch # 88169 is 4.142479129969795
# The value of the Gaussian NLL after Epoch # 88170 is 4.142479035193643
# The value of the Gaussian NLL after Epoch # 88171 is 4.142478869295551
# The value of the Gaussian NLL after Epoch # 88172 is 4.142478717739766
# The value of the Gaussian NLL after Epoch # 88173 is 4.142478568946898
# The value of the Gaussian NLL after Epoch # 88174 is 4.142478491288278
# The value of the Gaussian NLL after Epoch # 88175 is 4.142478339751172
# The value of the Gaussian NLL after Epoch # 88176 is 4.142478188220337
# The value of the Gaussian NLL after Epoch # 88177 is 4.142477897196141
# The value of the Gaussian NLL after Epoch # 88178 is 4.142477873597422
# The value of the Gaussian NLL after Epoch # 88179 is 4.142477636620791
# The value of the Gaussian NLL after Epoch # 88180 is 4.1424774851148065
# The value of the Gaussian NLL after Epoch # 88181 is 4.142477407499467
# The value of the Gaussian NLL after Epoch # 88182 is 4.142477256005957
# The value of the Gaussian NLL after Epoch # 88183 is 4.142477053239937
# The value of the Gaussian NLL after Epoch # 88184 is 4.142476887422262
# The value of the Gaussian NLL after Epoch # 88185 is 4.142476792738716
# The value of the Gaussian NLL after Epoch # 88186 is 4.142476641270075
# The value of the Gaussian NLL after Epoch # 88187 is 4.142476421435948
# The value of the Gaussian NLL after Epoch # 88188 is 4.142476326770925
# The value of the Gaussian NLL after Epoch # 88189 is 4.1424761753209465
# The value of the Gaussian NLL after Epoch # 88190 is 4.142475972598373
# The value of the Gaussian NLL after Epoch # 88191 is 4.142475877951876
# The value of the Gaussian NLL after Epoch # 88192 is 4.142475726520576
# The value of the Gaussian NLL after Epoch # 88193 is 4.14247556075856
# The value of the Gaussian NLL after Epoch # 88194 is 4.142475409339719
# The value of the Gaussian NLL after Epoch # 88195 is 4.142475189555213
# The value of the Gaussian NLL after Epoch # 88196 is 4.142475094939596
# The value of the Gaussian NLL after Epoch # 88197 is 4.142474943539419
# The value of the Gaussian NLL after Epoch # 88198 is 4.142474740866512
# The value of the Gaussian NLL after Epoch # 88199 is 4.142474646269419
# The value of the Gaussian NLL after Epoch # 88200 is 4.142474494887923
# The value of the Gaussian NLL after Epoch # 88201 is 4.142474329175397
# The value of the Gaussian NLL after Epoch # 88202 is 4.142474177806358
# The value of the Gaussian NLL after Epoch # 88203 is 4.142474029199229
# The value of the Gaussian NLL after Epoch # 88204 is 4.142473863505263
# The value of the Gaussian NLL after Epoch # 88205 is 4.142473712154887
# The value of the Gaussian NLL after Epoch # 88206 is 4.1424736176010155
# The value of the Gaussian NLL after Epoch # 88207 is 4.1424734662631
# The value of the Gaussian NLL after Epoch # 88208 is 4.142473263652265
# The value of the Gaussian NLL after Epoch # 88209 is 4.142473097989231
# The value of the Gaussian NLL after Epoch # 88210 is 4.1424729466699945
# The value of the Gaussian NLL after Epoch # 88211 is 4.142472798112402
# The value of the Gaussian NLL after Epoch # 88212 is 4.142472632467927
# The value of the Gaussian NLL after Epoch # 88213 is 4.142472481167355
# The value of the Gaussian NLL after Epoch # 88214 is 4.142472386662888
# The value of the Gaussian NLL after Epoch # 88215 is 4.142472235374774
# The value of the Gaussian NLL after Epoch # 88216 is 4.14247210394123
# The value of the Gaussian NLL after Epoch # 88217 is 4.142471867200065
# The value of the Gaussian NLL after Epoch # 88218 is 4.14247171593063
# The value of the Gaussian NLL after Epoch # 88219 is 4.142471621457047
# The value of the Gaussian NLL after Epoch # 88220 is 4.142471470200071
# The value of the Gaussian NLL after Epoch # 88221 is 4.142471250576821
# The value of the Gaussian NLL after Epoch # 88222 is 4.142471156121762
# The value of the Gaussian NLL after Epoch # 88223 is 4.14247100488345
# The value of the Gaussian NLL after Epoch # 88224 is 4.142470873499489
# The value of the Gaussian NLL after Epoch # 88225 is 4.142470636807902
# The value of the Gaussian NLL after Epoch # 88226 is 4.142470613505037
# The value of the Gaussian NLL after Epoch # 88227 is 4.142470462291594
# The value of the Gaussian NLL after Epoch # 88228 is 4.142470171584262
# The value of the Gaussian NLL after Epoch # 88229 is 4.142470148299887
# The value of the Gaussian NLL after Epoch # 88230 is 4.142469997105107
# The value of the Gaussian NLL after Epoch # 88231 is 4.142469845916597
# The value of the Gaussian NLL after Epoch # 88232 is 4.142469643454753
# The value of the Gaussian NLL after Epoch # 88233 is 4.142469477940175
# The value of the Gaussian NLL after Epoch # 88234 is 4.142469326770345
# The value of the Gaussian NLL after Epoch # 88235 is 4.142469232395561
# The value of the Gaussian NLL after Epoch # 88236 is 4.142469081238189
# The value of the Gaussian NLL after Epoch # 88237 is 4.142468861714168
# The value of the Gaussian NLL after Epoch # 88238 is 4.142468767357907
# The value of the Gaussian NLL after Epoch # 88239 is 4.1424686162192
# The value of the Gaussian NLL after Epoch # 88240 is 4.142468413807024
# The value of the Gaussian NLL after Epoch # 88241 is 4.142468319469289
# The value of the Gaussian NLL after Epoch # 88242 is 4.142468099976277
# The value of the Gaussian NLL after Epoch # 88243 is 4.14246800565088
# The value of the Gaussian NLL after Epoch # 88244 is 4.142467854543247
# The value of the Gaussian NLL after Epoch # 88245 is 4.142467703441884
# The value of the Gaussian NLL after Epoch # 88246 is 4.142467538007717
# The value of the Gaussian NLL after Epoch # 88247 is 4.142467389673002
# The value of the Gaussian NLL after Epoch # 88248 is 4.142467241344473
# The value of the Gaussian NLL after Epoch # 88249 is 4.14246709026798
# The value of the Gaussian NLL after Epoch # 88250 is 4.142466870824593
# The value of the Gaussian NLL after Epoch # 88251 is 4.142466776548602
# The value of the Gaussian NLL after Epoch # 88252 is 4.142466625490772
# The value of the Gaussian NLL after Epoch # 88253 is 4.142466460099911
# The value of the Gaussian NLL after Epoch # 88254 is 4.14246630905454
# The value of the Gaussian NLL after Epoch # 88255 is 4.142466160769366
# The value of the Gaussian NLL after Epoch # 88256 is 4.142466012490375
# The value of the Gaussian NLL after Epoch # 88257 is 4.142465861463684
# The value of the Gaussian NLL after Epoch # 88258 is 4.1424656961037565
# The value of the Gaussian NLL after Epoch # 88259 is 4.14246554784334
# The value of the Gaussian NLL after Epoch # 88260 is 4.142465396835314
# The value of the Gaussian NLL after Epoch # 88261 is 4.142465231493947
# The value of the Gaussian NLL after Epoch # 88262 is 4.142465083252106
# The value of the Gaussian NLL after Epoch # 88263 is 4.142464932262743
# The value of the Gaussian NLL after Epoch # 88264 is 4.142464855160389
# The value of the Gaussian NLL after Epoch # 88265 is 4.142464704183501
# The value of the Gaussian NLL after Epoch # 88266 is 4.142464467745972
# The value of the Gaussian NLL after Epoch # 88267 is 4.1424643167815445
# The value of the Gaussian NLL after Epoch # 88268 is 4.1424642397039335
# The value of the Gaussian NLL after Epoch # 88269 is 4.142464003285001
# The value of the Gaussian NLL after Epoch # 88270 is 4.142463852339238
# The value of the Gaussian NLL after Epoch # 88271 is 4.142463829313789
# The value of the Gaussian NLL after Epoch # 88272 is 4.1424636783804845
# The value of the Gaussian NLL after Epoch # 88273 is 4.142463476173157
# The value of the Gaussian NLL after Epoch # 88274 is 4.142463310912199
# The value of the Gaussian NLL after Epoch # 88275 is 4.1424631599975745
# The value of the Gaussian NLL after Epoch # 88276 is 4.142463011842429
# The value of the Gaussian NLL after Epoch # 88277 is 4.142462775473077
# The value of the Gaussian NLL after Epoch # 88278 is 4.142462752490764
# The value of the Gaussian NLL after Epoch # 88279 is 4.142462601600992
# The value of the Gaussian NLL after Epoch # 88280 is 4.142462450717492

# %%
list(MLEstimatorNN.parameters())
# Out:
# [Parameter containing:
#  tensor([-108.8365], requires_grad=True),
#  Parameter containing:
#  tensor([2.7219], requires_grad=True)]
